# %% [markdown]
# # BlackJack : Monte-Carlo with Exploring Start
# ----
#
# ## 설명
# 블랙잭 게임에서의 최적 Policy를 찾는 프로그램입니다. 본 프로그램에서 정의된 블랙잭 룰은 다음과 같습니다.
#  - 하나의 카드 덱(조커를 제외한 52장의 카드)을 사용
#  - 카드의 합을 계산할 시 A = 1 or 11, J,Q,K = 10으로 계산
#  - 플레이어는 Hit 또는 Stick만을 할 수 있음
#  - 카드의 합이 21 이하일 경우, 딜러와 플레이어 중 숫자가 더 높은 쪽이 승리.
#  - 카드의 합이 21 초과한 딜러/플레이어는 패배
#  - 카드의 합이 같을 경우 무승부
#
# 본 프로그램에서는 최적 Policy를 찾기 위해 Monte-Carlo Control with Exploring Start[1] 알고리즘을 사용합니다. 최적 Policy를 찾기 위해, 본 프로그램은 다음과 같은 변수로 구성된 State로부터 탐색을 수행합니다.
#  - 플레이어 카드의 합 : 12 ~ 21 사이의 정수
#  - 딜러가 보여주는 카드의 숫자 : 1 ~ 10 사이의 정수
#  - 플레이어가 현재 사용 가능한 Ace의 유무 : True / False
#
# 위와 같이 구성된 State S에서 Action A를 선택했을 때의 기대 리턴(게임이 끝났을 때 얻을 것으로 기대되는 보상의 합)은 Q(S,A)입니다. 많은 에피소드를 경험할수혹 Agent는 Optimal Q(S,A)에 가까운 값을 학습하게 되며, 이로부터 최적 Policy를 찾을 수 있습니다.
#
# ----
#
# ## 0. Package
# 먼저 본 프로그램에서 사용할 Package를 Import합니다.

# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

k = 0
popCnt = 0

# %% [markdown]
# ## 1. Class : Deck
# 카드 덱 한 벌에 해당하는 클래스를 선언합니다. 조커를 제외한 52장의 카드로 이루어져 있으며, 각 카드는 정수로 표기됩니다. <br>
# A = 11, J, Q, K = 10으로 표현되며, 나머지 카드는 해당 카드에 적힌 숫자만큼의 값을 갖습니다.
#
# ### 클래스 구성
# * Attributes
#    * card_deck : List, 52개의 정수로 이루어짐
# * Methods
#    * shuffle() : 카드 덱을 랜덤하게 섞음
#    * draw() : 카드 덱에서 한 장을 뽑아 리턴
#    * reset() : 카드 덱을 초기화함

# %%
class Deck(object):
    """
    Deck : Card deck, which can be shuffled, drawn, and reset.
    """
    
    
    def __init__(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()

    def shuffle(self):
        random.shuffle(self.card_deck)

    def draw(self):
        global popCnt
        popCnt += 1
        return self.card_deck.pop()

    def reset(self):
        global popCnt
        if popCnt > 27 :
            deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
            self.card_deck = deck * 4
            self.shuffle()
            popCnt =0

# %% [markdown]
# ## 2. Class : Dealer
# 다음으로 Dealer 클래스를 선언합니다.<br>
# Dealer 클래스는 강화학습에서의 Environment에 해당합니다. 플레이어의 Action을 받고, 그에 따른 다음 State와 Reward를 반환합니다.<br>
# 딜러는 시작할 때 두 장의 카드를 받습니다. 플레이어의 차례가 끝난 후, 플레이어의 카드 합이 21을 넘지 않는다면 딜러는 다음과 같이 행동합니다.
#  - 딜러 카드의 합이 17 미만일 때 : 카드 한 장을 추가로 뽑음 (Hit)
#  - 딜러 카드의 합이 17 이상일 때 : 플레이어의 카드 합과 비교하여 승패 결정 (Stick)
#
# ### 클래스 구성
# 딜러 클래스는 다음과 같이 구성됩니다
#  - Attributes
#      - hands : List, 딜러가 가지고 있는 카드들
#      - usable_ace : List, 딜러가 가지고 있는 A의 인덱스
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - show() : 딜러가 가진 카드 중 랜덤한 한 장의 값을 리턴
#      - calculate_sum() : 딜러가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - action() : 딜러의 Action - 합이 17 미만이면 hit, 이상이면 stick
#      - observation(action, agent, deck) : 플레이어의 action을 받아 종료 여부와 reward 리턴
#      - calculate_rewards(agent, deck) : 플레이어와 딜러의 승패 계산 및 reward 리턴
#      - reset() : 딜러 클래스의 모든 attribute 초기화

# %%
class Dealer(object):
    """
    Dealer : 딜러 클래스
    딜러는 두 장의 카드를 받고, 카드의 합이 16 이하이면 Hit, 17이상이면 Stick 함.
    처음 두 장을 받았을 때 한 장의 카드를 랜덤하게 오픈함.
    """

    def __init__(self):
        """
        hand : 딜러가 가진 카드
        usable_ace : 딜러가 가진 카드 리스트 중 ace의 인덱스
        natural : 두 장의 카드로 21이 되면 True, 아니면 False
        """
        self.hands = list()
        self.usable_ace = list()

    def hit(self, deck: Deck):
        """
        딜러의 Hit. 새로운 카드가 Ace라면 사용 가능한 Ace 리스트에 추가함
        :param deck: Deck Object
        :return:
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def show(self):
        """
        딜러가 가진 카드 중 하나를 랜덤하게 보여줌
        :return: 딜러의 카드 중 랜덤한 카드 숫자
        """
        card = random.choice(self.hands)
        if card == 11:
            card = 1
        return card

    def calculate_sum(self):
        """
        딜러가 가진 카드의 합을 구함
        21을 넘을 때 사용 가능한 Ace가 있으면 사용함
        :return: 딜러 카드의 합
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def action(self, deck: Deck):
        """
        딜러의 순서 때 딜러의 행동.
        숫자의 합이 16 이하일 때는 Hit, 17 이상이면 Stick
        :param deck:
        :return:
        """
        while True:
            sums = self.calculate_sum()
            if sums < 17:
                self.hit(deck)
            else:
                return sums

    def observation(self, action, agent, deck):
        """
        플레이어의 Action을 받아, 그에 맞는 Observation과 Reward를 반환
        :param action: agent 의 Action
        :param agent: agent 클래스
        :param deck: deck 클래스
        :return: 에피소드 종료 여부, reward
        """
        done = False
        reward = 0
        if action == True:  # Hit
            agent.hit(deck)
            if agent.calculate_sum() > 21:  #플레이어의 Hit으로 인해 카드 합이 21이 넘으면 즉시 종료
                done = True
                reward = -1
        else:  # Stick
            done = True
            reward = self.calcuate_reward(agent, deck)

        return done, reward

    def calcuate_reward(self, agent, deck):
        """
        플레이어가 Stick했을 때 딜러와의 카드 비교 수행
        :param agent:
        :param deck:
        :return: Reward
        """
        agent_sum = agent.calculate_sum()           # 플레이어의 카드 합 계산
        if agent_sum > 21:                          # 플레이어의 Bust (패)
            return -1

        dealer_sum = self.action(deck)              # 딜러의 카드 합 계산
        if dealer_sum > 21:                         # 딜러가 Bust (승)
            return 1
        if dealer_sum > agent_sum:                  # 딜러의 카드 합 > 플레이어 합 (패)
            return -1
        if dealer_sum < agent_sum:                  # 딜러의 카드 합 < 플레이어 합 (승)
            return 1
        return 0                                   # 딜러의 카드 합 == 플레이어의 합 (무)

    def reset(self):
        """
        딜러 초기화 (새로운 에피소드 시작을 위해)
        """
        self.hands = list()
        self.usable_ace = list()
        
    def handCnt(self):
        return len(self.hands)

# %% [markdown]
# ## 3. Class : Agent
# Agent 클래스는 플레이어에 해당하며, 최적 Policy를 학습하는 주체가 됩니다. Agent는 여러 에피소드들로부터 Q값(기대 Return)을 계산하고, 다음 에피소드 수행 시 해당 State에서 Q값이 높은 Action을 선택하는 Greedy Policy를 따릅니다.
#
# ### 클래스 구성
#
# Agent의 구성은 다음과 같습니다.
#
#  - Attributes
#      - hands : List, Agent가 가지고 있는 카드들
#      - usable_ace : List, Agent가 가지고 있는 A의 인덱스
#      - Q_table : Dictionary, 기대 Return값과 방문 횟수를 저장
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - calculate_sum() : Agent가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - random_action() : 현재 State에 상관없이 랜덤하게 Action을 리턴
#      - policy(state) : 현재 State에서 가능한 Action 중, Q_table의 값이 큰 Action을 리턴
#      - update_qval(episode) : 에피소드로부터 평균 리턴을 계산하여 Q_table을 업데이트
#      - reset() : Agent 클래스의 모든 attribute 초기화

# %%
class Agent(object):
    def __init__(self):
        """
        hand : 플레이어의 카드
        usable_ace : 사용 가능한 ace 리스트
        Q_table : q(s,a) 값을 저장할 딕셔너리
        """
        self.hands = list()
        self.usable_ace = list()
        self.Q_table = dict()

    def hit(self, deck: Deck):
        """
        덱에서 새로운 카드를 뽑음
        :param deck: Deck for draw a card
        :return: None
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def calculate_sum(self):
        """
        플레이어가 가진 카드의 합을 구함.
        21을 넘을 때 사용 가능한 ace가 있으면 사용함
        :return:
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def random_action(self):
        """
        랜덤하게 행동
        True = hit, False = stick
        :return:
        """
        return random.choice([True, False])

    def policy(self, state):
        """
        Agent의 policy 함수.
        e의 확률로 랜덤 행동을 하며, 그 외에는 현재 state에서 큰 q(s,a)값을 갖는 action을 선택함
        :param state: Agent에게 주어진 state
        :return: agent의 action을 반환 , True = hit and False = stick
        """
        # Q_table에서 현재 state-action에 대해 값이 존재하는지 검사함
        for action in (True, False):
            if (state, action) not in self.Q_table.keys():  # Q_table에 값이 없으면 0으로 초기화
                self.Q_table[(state, action)] = [0, 0]      # (mean return, visit count)
            else:
                continue

        # q값이 큰 action 선택
        if self.Q_table[(state, True)] > self.Q_table[(state, False)]:
            return True     # Hit
        elif self.Q_table[(state, True)] == self.Q_table[(state, False)]:   # q값이 같으면 무작위추출
            return self.random_action()
        else:
            return False    # Stick


    def reset(self):
        """
        Agent를 리셋함
        :return: None
        """
        self.hands = list()
        self.usable_ace = list()

    def update_qval(self, episode):
        """
        에피소드(한 번의 게임)으로부터 Q_table 을 업데이트함
        Q 테이블에 없는 state-action 쌍이 나오면 새로 생성
        Q 테이블에 state-action 쌍이 존재한다면 Incremental mean 적용하여 업데이트
        :param episode: Episode generated from environment
        :return: None
        """
        total_return = 0
        for state, action, reward in episode[::-1]:     # 에피소드의 뒤에서부터 (역순)
            total_return += reward                       # return Gt 계산
            if (state, action) not in self.Q_table.keys():  # state-action 쌍이 없다면
                self.Q_table[(state, action)] = [total_return, 1]   # 새롭게 엔트리 생성 (Gt, count)

            else:  #이미 존재하는 state-action 쌍이면 Incremental mean 적용
                prev_val = self.Q_table[(state, action)][0]         # 이전의 평균 return
                count = self.Q_table[(state, action)][1] + 1        # count 증가
                mean = prev_val + (total_return - prev_val) / count # 평균 계산 : Incremental Mean 적용
                self.Q_table[(state, action)] = [mean, count]  # 업데이트
                
                
    def handCnt(self):
        return len(self.hands)

# %% [markdown]
# ## 4. Class : MonteCarlo
# Monte-Carlo control with Exploring Start를 구현한 클래스입니다. 에피소드를 생성할 수 있고, 생성된 에피소드로부터 에이전트를 학습시킵니다.
# 에피소드 생성 시 Exploring Start를 위해 에피소드의 첫 번째 State에서는 무작위로 Action을 선택하며, 이후에는 에이전트의 Policy를 따라 Action을 선택합니다.
#
# ### 클래스 구성
# MonteCarlo 클래스는 다음과 같이 구성됩니다.
#  - Attribute
#      - 없음
#  - Methods
#      - generate_episode(dealer, agent, deck) : 딜러, 플레이어, 카드 덱을 이용해 한 번의 블랙잭 게임을 진행하고 에피소드를 반환합니다.
#      - train(dealer, agent, deck, it, verbose) : 지정된 이터레이션 수만큼의 에피소드로부터 플레이어를 학습시킵니다.

# %%
class MonteCarlo(object):
    def generate_episode(self, dealer: Dealer, agent: Agent, deck: Deck):
        """
        하나의 에피소드(게임)를 생성함
        :param dealer:
        :param agent:
        :param deck:
        :return:
        """
        
        global k
        k += 1
        #남은 게임 15장 이상이면 덱 그대로 사용, 남은 카드 15장 미만이면 덱 초기화
        #remainCard = len(deck.card_deck)
        
        #remainCard = 52 - dealer.handCnt() - agent.handCnt()
        
        # 카드 덱, 딜러, Agent를 초기화
        
        

#         if k==1 :
# #             deck.reset()
# #             dealer.reset()
# #             agent.reset()
            
#         if k>1 and remainCard < 15 :
#             deck.reset()
#             dealer.reset()
#             agent.reset()
    
        deck.reset()
        dealer.reset()
        agent.reset()
        agent.hit(deck)
        agent.hit(deck)
        dealer.hit(deck)
        dealer.hit(deck)

        done = False    # 에피소드의 종료 여부

        episode = list()    # 에피소드

        while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
            sums = agent.calculate_sum()
            if sums < 12:
                agent.hit(deck)
                continue

            state = (sums, bool(agent.usable_ace), dealer.show())

            ########   Exploring Start ~!!!!!!!!! : 
            if len(episode) == 0:       # 첫번째 State 일 때는 무작위 Action 선택
                action =agent.random_action()
            else:                       # 그 외에는 Q 테이블에서 큰 값을 갖는 Action 선택
                action = agent.policy(state)
            
            done, reward = dealer.observation(action, agent, deck)  # 에피소드 종료 여부, Reward 계산
            
            # 생성된 State, Action, Reward를 에피소드에 추가
            episode.append([state, action, reward])

        return episode

    def train(self, dealer: Dealer, agent: Agent, deck: Deck, it=10000, verbose=True):
        count = 0
        win = 0
        loss = 0
        draw = 0
        total_win = 0
        total_loss = 0
        total_draw = 0
        result = str()
        for i in range(it):
            count += 1
            episode = self.generate_episode(dealer, agent, deck)
            agent.update_qval(episode)

            if episode[-1][-1] == 1:
                win += 1
            elif episode[-1][-1] == 0:
                draw += 1
            else:
                loss += 1

            if count % 1000 == 0 and verbose == True:
                total_win += win
                total_loss += loss
                total_draw += draw

                print("========== Training : Episode ", count, " ===========")
                print("Recent 1000 games win rate :{:.3f}%".format(win / (win + loss) * 100))
                print(" -- 1000 Games WIN :", win, "DRAW :", draw, "LOSS :", loss)
                print("Total win rate : {:.3f}%".format(total_win / (total_win + total_loss) * 100))
                print(" -- TOTAL Games WIN :", total_win, "DRAW :", total_draw, "LOSS :", total_loss)

                win = 0
                loss = 0
                draw = 0

# %% [markdown]
# ## 5. Function : plot_q_val(agent, usable_ace)
# Q값을 시각화하기 위한 함수입니다.

# %%
def plot_q_val(agent: Agent, usable_ace=True):
    fig = plt.figure()
    ax = Axes3D(fig)

    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            v_val = max([agent.Q_table[((hand, usable_ace, d), True)][0], agent.Q_table[((hand, usable_ace, d), False)][0]])
            l.append(v_val)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)

    Z = np.array(Z_list).T

    ax.plot_wireframe(X, Y, Z)
    plt.show()

# %% [markdown]
# ## 6. Function : plot_q_val(agent, usable_ace)
# 최적 Policy를 시각화하기 위한 함수입니다.

# %%
def plot_action(agent: Agent, usable_ace=True):
    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    action = False

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            l.append(0 if agent.Q_table[((hand, usable_ace, d), True)][0] > agent.Q_table[((hand, usable_ace, d), False)][0] else 1)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)
    Z = np.array(Z_list).T

    data = Z[::-1,:]
    data = np.append(data, [0 for _ in range(Z[0].shape[0])]).reshape(-1,Z[0].shape[0])
    
    cmap=cm.coolwarm
    plt.imshow(data, cmap=cmap, extent=[1,11,11,21])

    plt.show()
    return X, Y, Z

# %% [markdown]
# ## 7. 최적 Policy 학습

# %%
deck = Deck()
dealer = Dealer()
agent = Agent()
mc_es = MonteCarlo()

mc_es.train(dealer, agent, deck, it=1000000)
# Out:
# ========== Training : Episode  1000  ===========
# Recent 1000 games win rate :32.381%
#  -- 1000 Games WIN : 306 DRAW : 55 LOSS : 639
# Total win rate : 32.381%
#  -- TOTAL Games WIN : 306 DRAW : 55 LOSS : 639
# ========== Training : Episode  2000  ===========
# Recent 1000 games win rate :34.216%
#  -- 1000 Games WIN : 323 DRAW : 56 LOSS : 621
# Total win rate : 33.298%
#  -- TOTAL Games WIN : 629 DRAW : 111 LOSS : 1260
# ========== Training : Episode  3000  ===========
# Recent 1000 games win rate :38.266%
#  -- 1000 Games WIN : 362 DRAW : 54 LOSS : 584
# Total win rate : 34.956%
#  -- TOTAL Games WIN : 991 DRAW : 165 LOSS : 1844
# ========== Training : Episode  4000  ===========
# Recent 1000 games win rate :36.198%
#  -- 1000 Games WIN : 337 DRAW : 69 LOSS : 594
# Total win rate : 35.263%
#  -- TOTAL Games WIN : 1328 DRAW : 234 LOSS : 2438
# ========== Training : Episode  5000  ===========
# Recent 1000 games win rate :37.368%
#  -- 1000 Games WIN : 355 DRAW : 50 LOSS : 595
# Total win rate : 35.687%
#  -- TOTAL Games WIN : 1683 DRAW : 284 LOSS : 3033
# ========== Training : Episode  6000  ===========
# Recent 1000 games win rate :35.414%
#  -- 1000 Games WIN : 329 DRAW : 71 LOSS : 600
# Total win rate : 35.642%
#  -- TOTAL Games WIN : 2012 DRAW : 355 LOSS : 3633
# ========== Training : Episode  7000  ===========
# Recent 1000 games win rate :35.132%
#  -- 1000 Games WIN : 332 DRAW : 55 LOSS : 613
# Total win rate : 35.569%
#  -- TOTAL Games WIN : 2344 DRAW : 410 LOSS : 4246
# ========== Training : Episode  8000  ===========
# Recent 1000 games win rate :33.262%
#  -- 1000 Games WIN : 311 DRAW : 65 LOSS : 624
# Total win rate : 35.282%
#  -- TOTAL Games WIN : 2655 DRAW : 475 LOSS : 4870
# ========== Training : Episode  9000  ===========
# Recent 1000 games win rate :34.815%
#  -- 1000 Games WIN : 329 DRAW : 55 LOSS : 616
# Total win rate : 35.230%
#  -- TOTAL Games WIN : 2984 DRAW : 530 LOSS : 5486
# ========== Training : Episode  10000  ===========
# Recent 1000 games win rate :35.450%
#  -- 1000 Games WIN : 335 DRAW : 55 LOSS : 610
# Total win rate : 35.252%
#  -- TOTAL Games WIN : 3319 DRAW : 585 LOSS : 6096
# ========== Training : Episode  11000  ===========
# Recent 1000 games win rate :34.501%
#  -- 1000 Games WIN : 325 DRAW : 58 LOSS : 617
# Total win rate : 35.184%
#  -- TOTAL Games WIN : 3644 DRAW : 643 LOSS : 6713
# ========== Training : Episode  12000  ===========
# Recent 1000 games win rate :35.047%
#  -- 1000 Games WIN : 334 DRAW : 47 LOSS : 619
# Total win rate : 35.172%
#  -- TOTAL Games WIN : 3978 DRAW : 690 LOSS : 7332
# ========== Training : Episode  13000  ===========
# Recent 1000 games win rate :36.931%
#  -- 1000 Games WIN : 349 DRAW : 55 LOSS : 596
# Total win rate : 35.308%
#  -- TOTAL Games WIN : 4327 DRAW : 745 LOSS : 7928
# ========== Training : Episode  14000  ===========
# Recent 1000 games win rate :36.055%
#  -- 1000 Games WIN : 340 DRAW : 57 LOSS : 603
# Total win rate : 35.361%
#  -- TOTAL Games WIN : 4667 DRAW : 802 LOSS : 8531
# ========== Training : Episode  15000  ===========
# Recent 1000 games win rate :34.773%
#  -- 1000 Games WIN : 330 DRAW : 51 LOSS : 619
# Total win rate : 35.322%
#  -- TOTAL Games WIN : 4997 DRAW : 853 LOSS : 9150
# ========== Training : Episode  16000  ===========
# Recent 1000 games win rate :35.903%
#  -- 1000 Games WIN : 340 DRAW : 53 LOSS : 607
# Total win rate : 35.358%
#  -- TOTAL Games WIN : 5337 DRAW : 906 LOSS : 9757
# ========== Training : Episode  17000  ===========
# Recent 1000 games win rate :36.022%
#  -- 1000 Games WIN : 335 DRAW : 70 LOSS : 595
# Total win rate : 35.397%
#  -- TOTAL Games WIN : 5672 DRAW : 976 LOSS : 10352
# ========== Training : Episode  18000  ===========
# Recent 1000 games win rate :34.249%
#  -- 1000 Games WIN : 324 DRAW : 54 LOSS : 622
# Total win rate : 35.333%
#  -- TOTAL Games WIN : 5996 DRAW : 1030 LOSS : 10974
# ========== Training : Episode  19000  ===========
# Recent 1000 games win rate :33.859%
#  -- 1000 Games WIN : 322 DRAW : 49 LOSS : 629
# Total win rate : 35.255%
#  -- TOTAL Games WIN : 6318 DRAW : 1079 LOSS : 11603
# ========== Training : Episode  20000  ===========
# Recent 1000 games win rate :35.325%
#  -- 1000 Games WIN : 337 DRAW : 46 LOSS : 617
# Total win rate : 35.258%
#  -- TOTAL Games WIN : 6655 DRAW : 1125 LOSS : 12220
# ========== Training : Episode  21000  ===========
# Recent 1000 games win rate :36.730%
#  -- 1000 Games WIN : 346 DRAW : 58 LOSS : 596
# Total win rate : 35.328%
#  -- TOTAL Games WIN : 7001 DRAW : 1183 LOSS : 12816
# ========== Training : Episode  22000  ===========
# Recent 1000 games win rate :36.383%
#  -- 1000 Games WIN : 338 DRAW : 71 LOSS : 591
# Total win rate : 35.375%
#  -- TOTAL Games WIN : 7339 DRAW : 1254 LOSS : 13407
# ========== Training : Episode  23000  ===========
# Recent 1000 games win rate :35.394%
#  -- 1000 Games WIN : 332 DRAW : 62 LOSS : 606
# Total win rate : 35.376%
#  -- TOTAL Games WIN : 7671 DRAW : 1316 LOSS : 14013
# ========== Training : Episode  24000  ===========
# Recent 1000 games win rate :32.839%
#  -- 1000 Games WIN : 310 DRAW : 56 LOSS : 634
# Total win rate : 35.270%
#  -- TOTAL Games WIN : 7981 DRAW : 1372 LOSS : 14647
# ========== Training : Episode  25000  ===========
# Recent 1000 games win rate :36.585%
#  -- 1000 Games WIN : 345 DRAW : 57 LOSS : 598
# Total win rate : 35.323%
#  -- TOTAL Games WIN : 8326 DRAW : 1429 LOSS : 15245
# ========== Training : Episode  26000  ===========
# Recent 1000 games win rate :34.549%
#  -- 1000 Games WIN : 322 DRAW : 68 LOSS : 610
# Total win rate : 35.294%
#  -- TOTAL Games WIN : 8648 DRAW : 1497 LOSS : 15855
# ========== Training : Episode  27000  ===========
# Recent 1000 games win rate :37.994%
#  -- 1000 Games WIN : 356 DRAW : 63 LOSS : 581
# Total win rate : 35.393%
#  -- TOTAL Games WIN : 9004 DRAW : 1560 LOSS : 16436
# ========== Training : Episode  28000  ===========
# Recent 1000 games win rate :34.435%
#  -- 1000 Games WIN : 323 DRAW : 62 LOSS : 615
# Total win rate : 35.359%
#  -- TOTAL Games WIN : 9327 DRAW : 1622 LOSS : 17051
# ========== Training : Episode  29000  ===========
# Recent 1000 games win rate :36.403%
#  -- 1000 Games WIN : 340 DRAW : 66 LOSS : 594
# Total win rate : 35.395%
#  -- TOTAL Games WIN : 9667 DRAW : 1688 LOSS : 17645
# ========== Training : Episode  30000  ===========
# Recent 1000 games win rate :35.631%
#  -- 1000 Games WIN : 336 DRAW : 57 LOSS : 607
# Total win rate : 35.403%
#  -- TOTAL Games WIN : 10003 DRAW : 1745 LOSS : 18252
# ========== Training : Episode  31000  ===========
# Recent 1000 games win rate :37.143%
#  -- 1000 Games WIN : 351 DRAW : 55 LOSS : 594
# Total win rate : 35.459%
#  -- TOTAL Games WIN : 10354 DRAW : 1800 LOSS : 18846
# ========== Training : Episode  32000  ===========
# Recent 1000 games win rate :35.707%
#  -- 1000 Games WIN : 336 DRAW : 59 LOSS : 605
# Total win rate : 35.467%
#  -- TOTAL Games WIN : 10690 DRAW : 1859 LOSS : 19451
# ========== Training : Episode  33000  ===========
# Recent 1000 games win rate :36.316%
#  -- 1000 Games WIN : 345 DRAW : 50 LOSS : 605
# Total win rate : 35.493%
#  -- TOTAL Games WIN : 11035 DRAW : 1909 LOSS : 20056
# ========== Training : Episode  34000  ===========
# Recent 1000 games win rate :36.825%
#  -- 1000 Games WIN : 348 DRAW : 55 LOSS : 597
# Total win rate : 35.532%
#  -- TOTAL Games WIN : 11383 DRAW : 1964 LOSS : 20653
# ========== Training : Episode  35000  ===========
# Recent 1000 games win rate :35.599%
#  -- 1000 Games WIN : 330 DRAW : 73 LOSS : 597
# Total win rate : 35.534%
#  -- TOTAL Games WIN : 11713 DRAW : 2037 LOSS : 21250
# ========== Training : Episode  36000  ===========
# Recent 1000 games win rate :34.183%
#  -- 1000 Games WIN : 322 DRAW : 58 LOSS : 620
# Total win rate : 35.496%
#  -- TOTAL Games WIN : 12035 DRAW : 2095 LOSS : 21870
# ========== Training : Episode  37000  ===========
# Recent 1000 games win rate :36.220%
#  -- 1000 Games WIN : 343 DRAW : 53 LOSS : 604
# Total win rate : 35.516%
#  -- TOTAL Games WIN : 12378 DRAW : 2148 LOSS : 22474
# ========== Training : Episode  38000  ===========
# Recent 1000 games win rate :35.857%
#  -- 1000 Games WIN : 341 DRAW : 49 LOSS : 610
# Total win rate : 35.525%
#  -- TOTAL Games WIN : 12719 DRAW : 2197 LOSS : 23084
# ========== Training : Episode  39000  ===========
# Recent 1000 games win rate :36.461%
#  -- 1000 Games WIN : 342 DRAW : 62 LOSS : 596
# Total win rate : 35.549%
#  -- TOTAL Games WIN : 13061 DRAW : 2259 LOSS : 23680
# ========== Training : Episode  40000  ===========
# Recent 1000 games win rate :34.685%
#  -- 1000 Games WIN : 325 DRAW : 63 LOSS : 612
# Total win rate : 35.527%
#  -- TOTAL Games WIN : 13386 DRAW : 2322 LOSS : 24292
# ========== Training : Episode  41000  ===========
# Recent 1000 games win rate :36.461%
#  -- 1000 Games WIN : 342 DRAW : 62 LOSS : 596
# Total win rate : 35.550%
#  -- TOTAL Games WIN : 13728 DRAW : 2384 LOSS : 24888
# ========== Training : Episode  42000  ===========
# Recent 1000 games win rate :37.131%
#  -- 1000 Games WIN : 352 DRAW : 52 LOSS : 596
# Total win rate : 35.588%
#  -- TOTAL Games WIN : 14080 DRAW : 2436 LOSS : 25484
# ========== Training : Episode  43000  ===========
# Recent 1000 games win rate :36.549%
#  -- 1000 Games WIN : 341 DRAW : 67 LOSS : 592
# Total win rate : 35.610%
#  -- TOTAL Games WIN : 14421 DRAW : 2503 LOSS : 26076
# ========== Training : Episode  44000  ===========
# Recent 1000 games win rate :34.681%
#  -- 1000 Games WIN : 326 DRAW : 60 LOSS : 614
# Total win rate : 35.589%
#  -- TOTAL Games WIN : 14747 DRAW : 2563 LOSS : 26690
# ========== Training : Episode  45000  ===========
# Recent 1000 games win rate :36.034%
#  -- 1000 Games WIN : 338 DRAW : 62 LOSS : 600
# Total win rate : 35.599%
#  -- TOTAL Games WIN : 15085 DRAW : 2625 LOSS : 27290
# ========== Training : Episode  46000  ===========
# Recent 1000 games win rate :38.136%
#  -- 1000 Games WIN : 360 DRAW : 56 LOSS : 584
# Total win rate : 35.654%
#  -- TOTAL Games WIN : 15445 DRAW : 2681 LOSS : 27874
# ========== Training : Episode  47000  ===========
# Recent 1000 games win rate :37.916%
#  -- 1000 Games WIN : 353 DRAW : 69 LOSS : 578
# Total win rate : 35.702%
#  -- TOTAL Games WIN : 15798 DRAW : 2750 LOSS : 28452
# ========== Training : Episode  48000  ===========
# Recent 1000 games win rate :37.648%
#  -- 1000 Games WIN : 349 DRAW : 73 LOSS : 578
# Total win rate : 35.742%
#  -- TOTAL Games WIN : 16147 DRAW : 2823 LOSS : 29030
# ========== Training : Episode  49000  ===========
# Recent 1000 games win rate :33.297%
#  -- 1000 Games WIN : 306 DRAW : 81 LOSS : 613
# Total win rate : 35.693%
#  -- TOTAL Games WIN : 16453 DRAW : 2904 LOSS : 29643
# ========== Training : Episode  50000  ===========
# Recent 1000 games win rate :38.197%
#  -- 1000 Games WIN : 356 DRAW : 68 LOSS : 576
# Total win rate : 35.743%
#  -- TOTAL Games WIN : 16809 DRAW : 2972 LOSS : 30219
# ========== Training : Episode  51000  ===========
# Recent 1000 games win rate :34.115%
#  -- 1000 Games WIN : 320 DRAW : 62 LOSS : 618
# Total win rate : 35.711%
#  -- TOTAL Games WIN : 17129 DRAW : 3034 LOSS : 30837
# ========== Training : Episode  52000  ===========
# Recent 1000 games win rate :37.473%
#  -- 1000 Games WIN : 350 DRAW : 66 LOSS : 584
# Total win rate : 35.744%
#  -- TOTAL Games WIN : 17479 DRAW : 3100 LOSS : 31421
# ========== Training : Episode  53000  ===========
# Recent 1000 games win rate :38.593%
#  -- 1000 Games WIN : 362 DRAW : 62 LOSS : 576
# Total win rate : 35.798%
#  -- TOTAL Games WIN : 17841 DRAW : 3162 LOSS : 31997
# ========== Training : Episode  54000  ===========
# Recent 1000 games win rate :33.650%
#  -- 1000 Games WIN : 319 DRAW : 52 LOSS : 629
# Total win rate : 35.758%
#  -- TOTAL Games WIN : 18160 DRAW : 3214 LOSS : 32626
# ========== Training : Episode  55000  ===========
# Recent 1000 games win rate :35.515%
#  -- 1000 Games WIN : 331 DRAW : 68 LOSS : 601
# Total win rate : 35.754%
#  -- TOTAL Games WIN : 18491 DRAW : 3282 LOSS : 33227
# ========== Training : Episode  56000  ===========
# Recent 1000 games win rate :34.509%
#  -- 1000 Games WIN : 323 DRAW : 64 LOSS : 613
# Total win rate : 35.731%
#  -- TOTAL Games WIN : 18814 DRAW : 3346 LOSS : 33840
# ========== Training : Episode  57000  ===========
# Recent 1000 games win rate :35.730%
#  -- 1000 Games WIN : 333 DRAW : 68 LOSS : 599
# Total win rate : 35.731%
#  -- TOTAL Games WIN : 19147 DRAW : 3414 LOSS : 34439
# ========== Training : Episode  58000  ===========
# Recent 1000 games win rate :36.047%
#  -- 1000 Games WIN : 341 DRAW : 54 LOSS : 605
# Total win rate : 35.737%
#  -- TOTAL Games WIN : 19488 DRAW : 3468 LOSS : 35044
# ========== Training : Episode  59000  ===========
# Recent 1000 games win rate :34.709%
#  -- 1000 Games WIN : 328 DRAW : 55 LOSS : 617
# Total win rate : 35.719%
#  -- TOTAL Games WIN : 19816 DRAW : 3523 LOSS : 35661
# ========== Training : Episode  60000  ===========
# Recent 1000 games win rate :34.108%
#  -- 1000 Games WIN : 323 DRAW : 53 LOSS : 624
# Total win rate : 35.692%
#  -- TOTAL Games WIN : 20139 DRAW : 3576 LOSS : 36285
# ========== Training : Episode  61000  ===========
# Recent 1000 games win rate :34.352%
#  -- 1000 Games WIN : 326 DRAW : 51 LOSS : 623
# Total win rate : 35.670%
#  -- TOTAL Games WIN : 20465 DRAW : 3627 LOSS : 36908
# ========== Training : Episode  62000  ===========
# Recent 1000 games win rate :32.588%
#  -- 1000 Games WIN : 306 DRAW : 61 LOSS : 633
# Total win rate : 35.620%
#  -- TOTAL Games WIN : 20771 DRAW : 3688 LOSS : 37541
# ========== Training : Episode  63000  ===========
# Recent 1000 games win rate :34.567%
#  -- 1000 Games WIN : 327 DRAW : 54 LOSS : 619
# Total win rate : 35.604%
#  -- TOTAL Games WIN : 21098 DRAW : 3742 LOSS : 38160
# ========== Training : Episode  64000  ===========
# Recent 1000 games win rate :36.267%
#  -- 1000 Games WIN : 342 DRAW : 57 LOSS : 601
# Total win rate : 35.614%
#  -- TOTAL Games WIN : 21440 DRAW : 3799 LOSS : 38761
# ========== Training : Episode  65000  ===========
# Recent 1000 games win rate :34.690%
#  -- 1000 Games WIN : 324 DRAW : 66 LOSS : 610
# Total win rate : 35.600%
#  -- TOTAL Games WIN : 21764 DRAW : 3865 LOSS : 39371
# ========== Training : Episode  66000  ===========
# Recent 1000 games win rate :35.637%
#  -- 1000 Games WIN : 330 DRAW : 74 LOSS : 596
# Total win rate : 35.600%
#  -- TOTAL Games WIN : 22094 DRAW : 3939 LOSS : 39967
# ========== Training : Episode  67000  ===========
# Recent 1000 games win rate :35.086%
#  -- 1000 Games WIN : 327 DRAW : 68 LOSS : 605
# Total win rate : 35.593%
#  -- TOTAL Games WIN : 22421 DRAW : 4007 LOSS : 40572
# ========== Training : Episode  68000  ===========
# Recent 1000 games win rate :36.325%
#  -- 1000 Games WIN : 344 DRAW : 53 LOSS : 603
# Total win rate : 35.604%
#  -- TOTAL Games WIN : 22765 DRAW : 4060 LOSS : 41175
# ========== Training : Episode  69000  ===========
# Recent 1000 games win rate :35.966%
#  -- 1000 Games WIN : 337 DRAW : 63 LOSS : 600
# Total win rate : 35.609%
#  -- TOTAL Games WIN : 23102 DRAW : 4123 LOSS : 41775
# ========== Training : Episode  70000  ===========
# Recent 1000 games win rate :37.197%
#  -- 1000 Games WIN : 353 DRAW : 51 LOSS : 596
# Total win rate : 35.632%
#  -- TOTAL Games WIN : 23455 DRAW : 4174 LOSS : 42371
# ========== Training : Episode  71000  ===========
# Recent 1000 games win rate :35.432%
#  -- 1000 Games WIN : 332 DRAW : 63 LOSS : 605
# Total win rate : 35.629%
#  -- TOTAL Games WIN : 23787 DRAW : 4237 LOSS : 42976
# ========== Training : Episode  72000  ===========
# Recent 1000 games win rate :35.546%
#  -- 1000 Games WIN : 332 DRAW : 66 LOSS : 602
# Total win rate : 35.628%
#  -- TOTAL Games WIN : 24119 DRAW : 4303 LOSS : 43578
# ========== Training : Episode  73000  ===========
# Recent 1000 games win rate :35.941%
#  -- 1000 Games WIN : 340 DRAW : 54 LOSS : 606
# Total win rate : 35.632%
#  -- TOTAL Games WIN : 24459 DRAW : 4357 LOSS : 44184
# ========== Training : Episode  74000  ===========
# Recent 1000 games win rate :35.563%
#  -- 1000 Games WIN : 335 DRAW : 58 LOSS : 607
# Total win rate : 35.631%
#  -- TOTAL Games WIN : 24794 DRAW : 4415 LOSS : 44791
# ========== Training : Episode  75000  ===========
# Recent 1000 games win rate :37.835%
#  -- 1000 Games WIN : 353 DRAW : 67 LOSS : 580
# Total win rate : 35.660%
#  -- TOTAL Games WIN : 25147 DRAW : 4482 LOSS : 45371
# ========== Training : Episode  76000  ===========
# Recent 1000 games win rate :36.691%
#  -- 1000 Games WIN : 346 DRAW : 57 LOSS : 597
# Total win rate : 35.674%
#  -- TOTAL Games WIN : 25493 DRAW : 4539 LOSS : 45968
# ========== Training : Episode  77000  ===========
# Recent 1000 games win rate :35.331%
#  -- 1000 Games WIN : 336 DRAW : 49 LOSS : 615
# Total win rate : 35.670%
#  -- TOTAL Games WIN : 25829 DRAW : 4588 LOSS : 46583
# ========== Training : Episode  78000  ===========
# Recent 1000 games win rate :34.963%
#  -- 1000 Games WIN : 329 DRAW : 59 LOSS : 612
# Total win rate : 35.660%
#  -- TOTAL Games WIN : 26158 DRAW : 4647 LOSS : 47195
# ========== Training : Episode  79000  ===========
# Recent 1000 games win rate :36.170%
#  -- 1000 Games WIN : 340 DRAW : 60 LOSS : 600
# Total win rate : 35.667%
#  -- TOTAL Games WIN : 26498 DRAW : 4707 LOSS : 47795
# ========== Training : Episode  80000  ===========
# Recent 1000 games win rate :35.906%
#  -- 1000 Games WIN : 335 DRAW : 67 LOSS : 598
# Total win rate : 35.670%
#  -- TOTAL Games WIN : 26833 DRAW : 4774 LOSS : 48393
# ========== Training : Episode  81000  ===========
# Recent 1000 games win rate :37.764%
#  -- 1000 Games WIN : 358 DRAW : 52 LOSS : 590
# Total win rate : 35.696%
#  -- TOTAL Games WIN : 27191 DRAW : 4826 LOSS : 48983
# ========== Training : Episode  82000  ===========
# Recent 1000 games win rate :36.698%
#  -- 1000 Games WIN : 349 DRAW : 49 LOSS : 602
# Total win rate : 35.708%
#  -- TOTAL Games WIN : 27540 DRAW : 4875 LOSS : 49585
# ========== Training : Episode  83000  ===========
# Recent 1000 games win rate :34.512%
#  -- 1000 Games WIN : 322 DRAW : 67 LOSS : 611
# Total win rate : 35.694%
#  -- TOTAL Games WIN : 27862 DRAW : 4942 LOSS : 50196
# ========== Training : Episode  84000  ===========
# Recent 1000 games win rate :35.730%
#  -- 1000 Games WIN : 333 DRAW : 68 LOSS : 599
# Total win rate : 35.694%
#  -- TOTAL Games WIN : 28195 DRAW : 5010 LOSS : 50795
# ========== Training : Episode  85000  ===========
# Recent 1000 games win rate :37.104%
#  -- 1000 Games WIN : 351 DRAW : 54 LOSS : 595
# Total win rate : 35.711%
#  -- TOTAL Games WIN : 28546 DRAW : 5064 LOSS : 51390
# ========== Training : Episode  86000  ===========
# Recent 1000 games win rate :36.421%
#  -- 1000 Games WIN : 346 DRAW : 50 LOSS : 604
# Total win rate : 35.719%
#  -- TOTAL Games WIN : 28892 DRAW : 5114 LOSS : 51994
# ========== Training : Episode  87000  ===========
# Recent 1000 games win rate :32.415%
#  -- 1000 Games WIN : 306 DRAW : 56 LOSS : 638
# Total win rate : 35.681%
#  -- TOTAL Games WIN : 29198 DRAW : 5170 LOSS : 52632
# ========== Training : Episode  88000  ===========
# Recent 1000 games win rate :35.928%
#  -- 1000 Games WIN : 337 DRAW : 62 LOSS : 601
# Total win rate : 35.684%
#  -- TOTAL Games WIN : 29535 DRAW : 5232 LOSS : 53233
# ========== Training : Episode  89000  ===========
# Recent 1000 games win rate :35.572%
#  -- 1000 Games WIN : 339 DRAW : 47 LOSS : 614
# Total win rate : 35.683%
#  -- TOTAL Games WIN : 29874 DRAW : 5279 LOSS : 53847
# ========== Training : Episode  90000  ===========
# Recent 1000 games win rate :35.193%
#  -- 1000 Games WIN : 328 DRAW : 68 LOSS : 604
# Total win rate : 35.677%
#  -- TOTAL Games WIN : 30202 DRAW : 5347 LOSS : 54451
# ========== Training : Episode  91000  ===========
# Recent 1000 games win rate :34.816%
#  -- 1000 Games WIN : 321 DRAW : 78 LOSS : 601
# Total win rate : 35.668%
#  -- TOTAL Games WIN : 30523 DRAW : 5425 LOSS : 55052
# ========== Training : Episode  92000  ===========
# Recent 1000 games win rate :34.574%
#  -- 1000 Games WIN : 325 DRAW : 60 LOSS : 615
# Total win rate : 35.656%
#  -- TOTAL Games WIN : 30848 DRAW : 5485 LOSS : 55667
# ========== Training : Episode  93000  ===========
# Recent 1000 games win rate :37.726%
#  -- 1000 Games WIN : 355 DRAW : 59 LOSS : 586
# Total win rate : 35.679%
#  -- TOTAL Games WIN : 31203 DRAW : 5544 LOSS : 56253
# ========== Training : Episode  94000  ===========
# Recent 1000 games win rate :36.653%
#  -- 1000 Games WIN : 346 DRAW : 56 LOSS : 598
# Total win rate : 35.689%
#  -- TOTAL Games WIN : 31549 DRAW : 5600 LOSS : 56851
# ========== Training : Episode  95000  ===========
# Recent 1000 games win rate :35.606%
#  -- 1000 Games WIN : 329 DRAW : 76 LOSS : 595
# Total win rate : 35.688%
#  -- TOTAL Games WIN : 31878 DRAW : 5676 LOSS : 57446
# ========== Training : Episode  96000  ===========
# Recent 1000 games win rate :36.763%
#  -- 1000 Games WIN : 343 DRAW : 67 LOSS : 590
# Total win rate : 35.699%
#  -- TOTAL Games WIN : 32221 DRAW : 5743 LOSS : 58036
# ========== Training : Episode  97000  ===========
# Recent 1000 games win rate :38.552%
#  -- 1000 Games WIN : 362 DRAW : 61 LOSS : 577
# Total win rate : 35.729%
#  -- TOTAL Games WIN : 32583 DRAW : 5804 LOSS : 58613
# ========== Training : Episode  98000  ===========
# Recent 1000 games win rate :34.086%
#  -- 1000 Games WIN : 317 DRAW : 70 LOSS : 613
# Total win rate : 35.712%
#  -- TOTAL Games WIN : 32900 DRAW : 5874 LOSS : 59226
# ========== Training : Episode  99000  ===========
# Recent 1000 games win rate :35.676%
#  -- 1000 Games WIN : 335 DRAW : 61 LOSS : 604
# Total win rate : 35.712%
#  -- TOTAL Games WIN : 33235 DRAW : 5935 LOSS : 59830
# ========== Training : Episode  100000  ===========
# Recent 1000 games win rate :36.296%
#  -- 1000 Games WIN : 339 DRAW : 66 LOSS : 595
# Total win rate : 35.717%
#  -- TOTAL Games WIN : 33574 DRAW : 6001 LOSS : 60425
# ========== Training : Episode  101000  ===========
# Recent 1000 games win rate :33.440%
#  -- 1000 Games WIN : 313 DRAW : 64 LOSS : 623
# Total win rate : 35.695%
#  -- TOTAL Games WIN : 33887 DRAW : 6065 LOSS : 61048
# ========== Training : Episode  102000  ===========
# Recent 1000 games win rate :34.620%
#  -- 1000 Games WIN : 323 DRAW : 67 LOSS : 610
# Total win rate : 35.684%
#  -- TOTAL Games WIN : 34210 DRAW : 6132 LOSS : 61658
# ========== Training : Episode  103000  ===========
# Recent 1000 games win rate :35.193%
#  -- 1000 Games WIN : 328 DRAW : 68 LOSS : 604
# Total win rate : 35.680%
#  -- TOTAL Games WIN : 34538 DRAW : 6200 LOSS : 62262
# ========== Training : Episode  104000  ===========
# Recent 1000 games win rate :36.635%
#  -- 1000 Games WIN : 344 DRAW : 61 LOSS : 595
# Total win rate : 35.689%
#  -- TOTAL Games WIN : 34882 DRAW : 6261 LOSS : 62857
# ========== Training : Episode  105000  ===========
# Recent 1000 games win rate :32.216%
#  -- 1000 Games WIN : 298 DRAW : 75 LOSS : 627
# Total win rate : 35.656%
#  -- TOTAL Games WIN : 35180 DRAW : 6336 LOSS : 63484
# ========== Training : Episode  106000  ===========
# Recent 1000 games win rate :35.737%
#  -- 1000 Games WIN : 337 DRAW : 57 LOSS : 606
# Total win rate : 35.657%
#  -- TOTAL Games WIN : 35517 DRAW : 6393 LOSS : 64090
# ========== Training : Episode  107000  ===========
# Recent 1000 games win rate :35.406%
#  -- 1000 Games WIN : 336 DRAW : 51 LOSS : 613
# Total win rate : 35.655%
#  -- TOTAL Games WIN : 35853 DRAW : 6444 LOSS : 64703
# ========== Training : Episode  108000  ===========
# Recent 1000 games win rate :34.505%
#  -- 1000 Games WIN : 324 DRAW : 61 LOSS : 615
# Total win rate : 35.644%
#  -- TOTAL Games WIN : 36177 DRAW : 6505 LOSS : 65318
# ========== Training : Episode  109000  ===========
# Recent 1000 games win rate :32.653%
#  -- 1000 Games WIN : 304 DRAW : 69 LOSS : 627
# Total win rate : 35.617%
#  -- TOTAL Games WIN : 36481 DRAW : 6574 LOSS : 65945
# ========== Training : Episode  110000  ===========
# Recent 1000 games win rate :34.936%
#  -- 1000 Games WIN : 327 DRAW : 64 LOSS : 609
# Total win rate : 35.611%
#  -- TOTAL Games WIN : 36808 DRAW : 6638 LOSS : 66554
# ========== Training : Episode  111000  ===========
# Recent 1000 games win rate :34.194%
#  -- 1000 Games WIN : 318 DRAW : 70 LOSS : 612
# Total win rate : 35.598%
#  -- TOTAL Games WIN : 37126 DRAW : 6708 LOSS : 67166
# ========== Training : Episode  112000  ===========
# Recent 1000 games win rate :36.730%
#  -- 1000 Games WIN : 346 DRAW : 58 LOSS : 596
# Total win rate : 35.608%
#  -- TOTAL Games WIN : 37472 DRAW : 6766 LOSS : 67762
# ========== Training : Episode  113000  ===========
# Recent 1000 games win rate :34.694%
#  -- 1000 Games WIN : 323 DRAW : 69 LOSS : 608
# Total win rate : 35.600%
#  -- TOTAL Games WIN : 37795 DRAW : 6835 LOSS : 68370
# ========== Training : Episode  114000  ===========
# Recent 1000 games win rate :34.677%
#  -- 1000 Games WIN : 327 DRAW : 57 LOSS : 616
# Total win rate : 35.592%
#  -- TOTAL Games WIN : 38122 DRAW : 6892 LOSS : 68986
# ========== Training : Episode  115000  ===========
# Recent 1000 games win rate :37.049%
#  -- 1000 Games WIN : 349 DRAW : 58 LOSS : 593
# Total win rate : 35.605%
#  -- TOTAL Games WIN : 38471 DRAW : 6950 LOSS : 69579
# ========== Training : Episode  116000  ===========
# Recent 1000 games win rate :35.362%
#  -- 1000 Games WIN : 337 DRAW : 47 LOSS : 616
# Total win rate : 35.603%
#  -- TOTAL Games WIN : 38808 DRAW : 6997 LOSS : 70195
# ========== Training : Episode  117000  ===========
# Recent 1000 games win rate :34.837%
#  -- 1000 Games WIN : 332 DRAW : 47 LOSS : 621
# Total win rate : 35.596%
#  -- TOTAL Games WIN : 39140 DRAW : 7044 LOSS : 70816
# ========== Training : Episode  118000  ===========
# Recent 1000 games win rate :35.300%
#  -- 1000 Games WIN : 329 DRAW : 68 LOSS : 603
# Total win rate : 35.594%
#  -- TOTAL Games WIN : 39469 DRAW : 7112 LOSS : 71419
# ========== Training : Episode  119000  ===========
# Recent 1000 games win rate :33.512%
#  -- 1000 Games WIN : 313 DRAW : 66 LOSS : 621
# Total win rate : 35.576%
#  -- TOTAL Games WIN : 39782 DRAW : 7178 LOSS : 72040
# ========== Training : Episode  120000  ===========
# Recent 1000 games win rate :35.129%
#  -- 1000 Games WIN : 326 DRAW : 72 LOSS : 602
# Total win rate : 35.573%
#  -- TOTAL Games WIN : 40108 DRAW : 7250 LOSS : 72642
# ========== Training : Episode  121000  ===========
# Recent 1000 games win rate :36.702%
#  -- 1000 Games WIN : 345 DRAW : 60 LOSS : 595
# Total win rate : 35.582%
#  -- TOTAL Games WIN : 40453 DRAW : 7310 LOSS : 73237
# ========== Training : Episode  122000  ===========
# Recent 1000 games win rate :35.169%
#  -- 1000 Games WIN : 332 DRAW : 56 LOSS : 612
# Total win rate : 35.578%
#  -- TOTAL Games WIN : 40785 DRAW : 7366 LOSS : 73849
# ========== Training : Episode  123000  ===========
# Recent 1000 games win rate :36.536%
#  -- 1000 Games WIN : 346 DRAW : 53 LOSS : 601
# Total win rate : 35.586%
#  -- TOTAL Games WIN : 41131 DRAW : 7419 LOSS : 74450
# ========== Training : Episode  124000  ===========
# Recent 1000 games win rate :37.085%
#  -- 1000 Games WIN : 346 DRAW : 67 LOSS : 587
# Total win rate : 35.598%
#  -- TOTAL Games WIN : 41477 DRAW : 7486 LOSS : 75037
# ========== Training : Episode  125000  ===========
# Recent 1000 games win rate :35.919%
#  -- 1000 Games WIN : 338 DRAW : 59 LOSS : 603
# Total win rate : 35.601%
#  -- TOTAL Games WIN : 41815 DRAW : 7545 LOSS : 75640
# ========== Training : Episode  126000  ===========
# Recent 1000 games win rate :35.593%
#  -- 1000 Games WIN : 336 DRAW : 56 LOSS : 608
# Total win rate : 35.601%
#  -- TOTAL Games WIN : 42151 DRAW : 7601 LOSS : 76248
# ========== Training : Episode  127000  ===========
# Recent 1000 games win rate :35.805%
#  -- 1000 Games WIN : 338 DRAW : 56 LOSS : 606
# Total win rate : 35.602%
#  -- TOTAL Games WIN : 42489 DRAW : 7657 LOSS : 76854
# ========== Training : Episode  128000  ===========
# Recent 1000 games win rate :34.906%
#  -- 1000 Games WIN : 333 DRAW : 46 LOSS : 621
# Total win rate : 35.597%
#  -- TOTAL Games WIN : 42822 DRAW : 7703 LOSS : 77475
# ========== Training : Episode  129000  ===========
# Recent 1000 games win rate :31.692%
#  -- 1000 Games WIN : 296 DRAW : 66 LOSS : 638
# Total win rate : 35.567%
#  -- TOTAL Games WIN : 43118 DRAW : 7769 LOSS : 78113
# ========== Training : Episode  130000  ===========
# Recent 1000 games win rate :35.005%
#  -- 1000 Games WIN : 328 DRAW : 63 LOSS : 609
# Total win rate : 35.563%
#  -- TOTAL Games WIN : 43446 DRAW : 7832 LOSS : 78722
# ========== Training : Episode  131000  ===========
# Recent 1000 games win rate :35.138%
#  -- 1000 Games WIN : 331 DRAW : 58 LOSS : 611
# Total win rate : 35.559%
#  -- TOTAL Games WIN : 43777 DRAW : 7890 LOSS : 79333
# ========== Training : Episode  132000  ===========
# Recent 1000 games win rate :34.468%
#  -- 1000 Games WIN : 324 DRAW : 60 LOSS : 616
# Total win rate : 35.551%
#  -- TOTAL Games WIN : 44101 DRAW : 7950 LOSS : 79949
# ========== Training : Episode  133000  ===========
# Recent 1000 games win rate :31.170%
#  -- 1000 Games WIN : 293 DRAW : 60 LOSS : 647
# Total win rate : 35.518%
#  -- TOTAL Games WIN : 44394 DRAW : 8010 LOSS : 80596
# ========== Training : Episode  134000  ===========
# Recent 1000 games win rate :34.926%
#  -- 1000 Games WIN : 329 DRAW : 58 LOSS : 613
# Total win rate : 35.514%
#  -- TOTAL Games WIN : 44723 DRAW : 8068 LOSS : 81209
# ========== Training : Episode  135000  ===========
# Recent 1000 games win rate :35.949%
#  -- 1000 Games WIN : 339 DRAW : 57 LOSS : 604
# Total win rate : 35.517%
#  -- TOTAL Games WIN : 45062 DRAW : 8125 LOSS : 81813
# ========== Training : Episode  136000  ===========
# Recent 1000 games win rate :38.996%
#  -- 1000 Games WIN : 365 DRAW : 64 LOSS : 571
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 45427 DRAW : 8189 LOSS : 82384
# ========== Training : Episode  137000  ===========
# Recent 1000 games win rate :34.368%
#  -- 1000 Games WIN : 321 DRAW : 66 LOSS : 613
# Total win rate : 35.534%
#  -- TOTAL Games WIN : 45748 DRAW : 8255 LOSS : 82997
# ========== Training : Episode  138000  ===========
# Recent 1000 games win rate :34.979%
#  -- 1000 Games WIN : 333 DRAW : 48 LOSS : 619
# Total win rate : 35.530%
#  -- TOTAL Games WIN : 46081 DRAW : 8303 LOSS : 83616
# ========== Training : Episode  139000  ===========
# Recent 1000 games win rate :35.026%
#  -- 1000 Games WIN : 331 DRAW : 55 LOSS : 614
# Total win rate : 35.526%
#  -- TOTAL Games WIN : 46412 DRAW : 8358 LOSS : 84230
# ========== Training : Episode  140000  ===========
# Recent 1000 games win rate :38.298%
#  -- 1000 Games WIN : 360 DRAW : 60 LOSS : 580
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 46772 DRAW : 8418 LOSS : 84810
# ========== Training : Episode  141000  ===========
# Recent 1000 games win rate :31.890%
#  -- 1000 Games WIN : 302 DRAW : 53 LOSS : 645
# Total win rate : 35.520%
#  -- TOTAL Games WIN : 47074 DRAW : 8471 LOSS : 85455
# ========== Training : Episode  142000  ===========
# Recent 1000 games win rate :35.164%
#  -- 1000 Games WIN : 333 DRAW : 53 LOSS : 614
# Total win rate : 35.517%
#  -- TOTAL Games WIN : 47407 DRAW : 8524 LOSS : 86069
# ========== Training : Episode  143000  ===========
# Recent 1000 games win rate :35.714%
#  -- 1000 Games WIN : 330 DRAW : 76 LOSS : 594
# Total win rate : 35.519%
#  -- TOTAL Games WIN : 47737 DRAW : 8600 LOSS : 86663
# ========== Training : Episode  144000  ===========
# Recent 1000 games win rate :38.543%
#  -- 1000 Games WIN : 365 DRAW : 53 LOSS : 582
# Total win rate : 35.540%
#  -- TOTAL Games WIN : 48102 DRAW : 8653 LOSS : 87245
# ========== Training : Episode  145000  ===========
# Recent 1000 games win rate :35.307%
#  -- 1000 Games WIN : 334 DRAW : 54 LOSS : 612
# Total win rate : 35.538%
#  -- TOTAL Games WIN : 48436 DRAW : 8707 LOSS : 87857
# ========== Training : Episode  146000  ===========
# Recent 1000 games win rate :31.137%
#  -- 1000 Games WIN : 293 DRAW : 59 LOSS : 648
# Total win rate : 35.508%
#  -- TOTAL Games WIN : 48729 DRAW : 8766 LOSS : 88505
# ========== Training : Episode  147000  ===========
# Recent 1000 games win rate :37.419%
#  -- 1000 Games WIN : 348 DRAW : 70 LOSS : 582
# Total win rate : 35.521%
#  -- TOTAL Games WIN : 49077 DRAW : 8836 LOSS : 89087
# ========== Training : Episode  148000  ===========
# Recent 1000 games win rate :35.714%
#  -- 1000 Games WIN : 335 DRAW : 62 LOSS : 603
# Total win rate : 35.522%
#  -- TOTAL Games WIN : 49412 DRAW : 8898 LOSS : 89690
# ========== Training : Episode  149000  ===========
# Recent 1000 games win rate :34.431%
#  -- 1000 Games WIN : 324 DRAW : 59 LOSS : 617
# Total win rate : 35.515%
#  -- TOTAL Games WIN : 49736 DRAW : 8957 LOSS : 90307
# ========== Training : Episode  150000  ===========
# Recent 1000 games win rate :37.143%
#  -- 1000 Games WIN : 351 DRAW : 55 LOSS : 594
# Total win rate : 35.526%
#  -- TOTAL Games WIN : 50087 DRAW : 9012 LOSS : 90901
# ========== Training : Episode  151000  ===========
# Recent 1000 games win rate :35.714%
#  -- 1000 Games WIN : 340 DRAW : 48 LOSS : 612
# Total win rate : 35.527%
#  -- TOTAL Games WIN : 50427 DRAW : 9060 LOSS : 91513
# ========== Training : Episode  152000  ===========
# Recent 1000 games win rate :34.342%
#  -- 1000 Games WIN : 329 DRAW : 42 LOSS : 629
# Total win rate : 35.519%
#  -- TOTAL Games WIN : 50756 DRAW : 9102 LOSS : 92142
# ========== Training : Episode  153000  ===========
# Recent 1000 games win rate :36.432%
#  -- 1000 Games WIN : 341 DRAW : 64 LOSS : 595
# Total win rate : 35.525%
#  -- TOTAL Games WIN : 51097 DRAW : 9166 LOSS : 92737
# ========== Training : Episode  154000  ===========
# Recent 1000 games win rate :34.672%
#  -- 1000 Games WIN : 328 DRAW : 54 LOSS : 618
# Total win rate : 35.519%
#  -- TOTAL Games WIN : 51425 DRAW : 9220 LOSS : 93355
# ========== Training : Episode  155000  ===========
# Recent 1000 games win rate :35.814%
#  -- 1000 Games WIN : 332 DRAW : 73 LOSS : 595
# Total win rate : 35.521%
#  -- TOTAL Games WIN : 51757 DRAW : 9293 LOSS : 93950
# ========== Training : Episode  156000  ===========
# Recent 1000 games win rate :33.902%
#  -- 1000 Games WIN : 318 DRAW : 62 LOSS : 620
# Total win rate : 35.511%
#  -- TOTAL Games WIN : 52075 DRAW : 9355 LOSS : 94570
# ========== Training : Episode  157000  ===========
# Recent 1000 games win rate :35.853%
#  -- 1000 Games WIN : 332 DRAW : 74 LOSS : 594
# Total win rate : 35.513%
#  -- TOTAL Games WIN : 52407 DRAW : 9429 LOSS : 95164
# ========== Training : Episode  158000  ===========
# Recent 1000 games win rate :37.855%
#  -- 1000 Games WIN : 360 DRAW : 49 LOSS : 591
# Total win rate : 35.528%
#  -- TOTAL Games WIN : 52767 DRAW : 9478 LOSS : 95755
# ========== Training : Episode  159000  ===========
# Recent 1000 games win rate :34.778%
#  -- 1000 Games WIN : 329 DRAW : 54 LOSS : 617
# Total win rate : 35.523%
#  -- TOTAL Games WIN : 53096 DRAW : 9532 LOSS : 96372
# ========== Training : Episode  160000  ===========
# Recent 1000 games win rate :33.761%
#  -- 1000 Games WIN : 316 DRAW : 64 LOSS : 620
# Total win rate : 35.512%
#  -- TOTAL Games WIN : 53412 DRAW : 9596 LOSS : 96992
# ========== Training : Episode  161000  ===========
# Recent 1000 games win rate :38.420%
#  -- 1000 Games WIN : 360 DRAW : 63 LOSS : 577
# Total win rate : 35.530%
#  -- TOTAL Games WIN : 53772 DRAW : 9659 LOSS : 97569
# ========== Training : Episode  162000  ===========
# Recent 1000 games win rate :35.881%
#  -- 1000 Games WIN : 338 DRAW : 58 LOSS : 604
# Total win rate : 35.533%
#  -- TOTAL Games WIN : 54110 DRAW : 9717 LOSS : 98173
# ========== Training : Episode  163000  ===========
# Recent 1000 games win rate :37.927%
#  -- 1000 Games WIN : 355 DRAW : 64 LOSS : 581
# Total win rate : 35.547%
#  -- TOTAL Games WIN : 54465 DRAW : 9781 LOSS : 98754
# ========== Training : Episode  164000  ===========
# Recent 1000 games win rate :37.131%
#  -- 1000 Games WIN : 352 DRAW : 52 LOSS : 596
# Total win rate : 35.557%
#  -- TOTAL Games WIN : 54817 DRAW : 9833 LOSS : 99350
# ========== Training : Episode  165000  ===========
# Recent 1000 games win rate :39.297%
#  -- 1000 Games WIN : 369 DRAW : 61 LOSS : 570
# Total win rate : 35.580%
#  -- TOTAL Games WIN : 55186 DRAW : 9894 LOSS : 99920
# ========== Training : Episode  166000  ===========
# Recent 1000 games win rate :37.406%
#  -- 1000 Games WIN : 349 DRAW : 67 LOSS : 584
# Total win rate : 35.590%
#  -- TOTAL Games WIN : 55535 DRAW : 9961 LOSS : 100504
# ========== Training : Episode  167000  ===========
# Recent 1000 games win rate :34.490%
#  -- 1000 Games WIN : 328 DRAW : 49 LOSS : 623
# Total win rate : 35.584%
#  -- TOTAL Games WIN : 55863 DRAW : 10010 LOSS : 101127
# ========== Training : Episode  168000  ===========
# Recent 1000 games win rate :35.453%
#  -- 1000 Games WIN : 329 DRAW : 72 LOSS : 599
# Total win rate : 35.583%
#  -- TOTAL Games WIN : 56192 DRAW : 10082 LOSS : 101726
# ========== Training : Episode  169000  ===========
# Recent 1000 games win rate :35.294%
#  -- 1000 Games WIN : 336 DRAW : 48 LOSS : 616
# Total win rate : 35.581%
#  -- TOTAL Games WIN : 56528 DRAW : 10130 LOSS : 102342
# ========== Training : Episode  170000  ===========
# Recent 1000 games win rate :36.421%
#  -- 1000 Games WIN : 346 DRAW : 50 LOSS : 604
# Total win rate : 35.586%
#  -- TOTAL Games WIN : 56874 DRAW : 10180 LOSS : 102946
# ========== Training : Episode  171000  ===========
# Recent 1000 games win rate :33.404%
#  -- 1000 Games WIN : 315 DRAW : 57 LOSS : 628
# Total win rate : 35.573%
#  -- TOTAL Games WIN : 57189 DRAW : 10237 LOSS : 103574
# ========== Training : Episode  172000  ===========
# Recent 1000 games win rate :33.880%
#  -- 1000 Games WIN : 310 DRAW : 85 LOSS : 605
# Total win rate : 35.564%
#  -- TOTAL Games WIN : 57499 DRAW : 10322 LOSS : 104179
# ========== Training : Episode  173000  ===========
# Recent 1000 games win rate :36.161%
#  -- 1000 Games WIN : 341 DRAW : 57 LOSS : 602
# Total win rate : 35.567%
#  -- TOTAL Games WIN : 57840 DRAW : 10379 LOSS : 104781
# ========== Training : Episode  174000  ===========
# Recent 1000 games win rate :35.086%
#  -- 1000 Games WIN : 327 DRAW : 68 LOSS : 605
# Total win rate : 35.565%
#  -- TOTAL Games WIN : 58167 DRAW : 10447 LOSS : 105386
# ========== Training : Episode  175000  ===========
# Recent 1000 games win rate :34.657%
#  -- 1000 Games WIN : 323 DRAW : 68 LOSS : 609
# Total win rate : 35.559%
#  -- TOTAL Games WIN : 58490 DRAW : 10515 LOSS : 105995
# ========== Training : Episode  176000  ===========
# Recent 1000 games win rate :35.851%
#  -- 1000 Games WIN : 337 DRAW : 60 LOSS : 603
# Total win rate : 35.561%
#  -- TOTAL Games WIN : 58827 DRAW : 10575 LOSS : 106598
# ========== Training : Episode  177000  ===========
# Recent 1000 games win rate :34.718%
#  -- 1000 Games WIN : 326 DRAW : 61 LOSS : 613
# Total win rate : 35.556%
#  -- TOTAL Games WIN : 59153 DRAW : 10636 LOSS : 107211
# ========== Training : Episode  178000  ===========
# Recent 1000 games win rate :34.563%
#  -- 1000 Games WIN : 328 DRAW : 51 LOSS : 621
# Total win rate : 35.551%
#  -- TOTAL Games WIN : 59481 DRAW : 10687 LOSS : 107832
# ========== Training : Episode  179000  ===========
# Recent 1000 games win rate :37.380%
#  -- 1000 Games WIN : 351 DRAW : 61 LOSS : 588
# Total win rate : 35.561%
#  -- TOTAL Games WIN : 59832 DRAW : 10748 LOSS : 108420
# ========== Training : Episode  180000  ===========
# Recent 1000 games win rate :35.155%
#  -- 1000 Games WIN : 328 DRAW : 67 LOSS : 605
# Total win rate : 35.559%
#  -- TOTAL Games WIN : 60160 DRAW : 10815 LOSS : 109025
# ========== Training : Episode  181000  ===========
# Recent 1000 games win rate :33.439%
#  -- 1000 Games WIN : 316 DRAW : 55 LOSS : 629
# Total win rate : 35.547%
#  -- TOTAL Games WIN : 60476 DRAW : 10870 LOSS : 109654
# ========== Training : Episode  182000  ===========
# Recent 1000 games win rate :38.871%
#  -- 1000 Games WIN : 365 DRAW : 61 LOSS : 574
# Total win rate : 35.565%
#  -- TOTAL Games WIN : 60841 DRAW : 10931 LOSS : 110228
# ========== Training : Episode  183000  ===========
# Recent 1000 games win rate :34.677%
#  -- 1000 Games WIN : 327 DRAW : 57 LOSS : 616
# Total win rate : 35.560%
#  -- TOTAL Games WIN : 61168 DRAW : 10988 LOSS : 110844
# ========== Training : Episode  184000  ===========
# Recent 1000 games win rate :36.943%
#  -- 1000 Games WIN : 348 DRAW : 58 LOSS : 594
# Total win rate : 35.568%
#  -- TOTAL Games WIN : 61516 DRAW : 11046 LOSS : 111438
# ========== Training : Episode  185000  ===========
# Recent 1000 games win rate :34.346%
#  -- 1000 Games WIN : 328 DRAW : 45 LOSS : 627
# Total win rate : 35.561%
#  -- TOTAL Games WIN : 61844 DRAW : 11091 LOSS : 112065
# ========== Training : Episode  186000  ===========
# Recent 1000 games win rate :33.868%
#  -- 1000 Games WIN : 317 DRAW : 64 LOSS : 619
# Total win rate : 35.552%
#  -- TOTAL Games WIN : 62161 DRAW : 11155 LOSS : 112684
# ========== Training : Episode  187000  ===========
# Recent 1000 games win rate :33.405%
#  -- 1000 Games WIN : 311 DRAW : 69 LOSS : 620
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 62472 DRAW : 11224 LOSS : 113304
# ========== Training : Episode  188000  ===========
# Recent 1000 games win rate :38.936%
#  -- 1000 Games WIN : 366 DRAW : 60 LOSS : 574
# Total win rate : 35.559%
#  -- TOTAL Games WIN : 62838 DRAW : 11284 LOSS : 113878
# ========== Training : Episode  189000  ===========
# Recent 1000 games win rate :34.110%
#  -- 1000 Games WIN : 322 DRAW : 56 LOSS : 622
# Total win rate : 35.551%
#  -- TOTAL Games WIN : 63160 DRAW : 11340 LOSS : 114500
# ========== Training : Episode  190000  ===========
# Recent 1000 games win rate :36.635%
#  -- 1000 Games WIN : 344 DRAW : 61 LOSS : 595
# Total win rate : 35.557%
#  -- TOTAL Games WIN : 63504 DRAW : 11401 LOSS : 115095
# ========== Training : Episode  191000  ===========
# Recent 1000 games win rate :36.741%
#  -- 1000 Games WIN : 345 DRAW : 61 LOSS : 594
# Total win rate : 35.563%
#  -- TOTAL Games WIN : 63849 DRAW : 11462 LOSS : 115689
# ========== Training : Episode  192000  ===========
# Recent 1000 games win rate :38.045%
#  -- 1000 Games WIN : 358 DRAW : 59 LOSS : 583
# Total win rate : 35.576%
#  -- TOTAL Games WIN : 64207 DRAW : 11521 LOSS : 116272
# ========== Training : Episode  193000  ===========
# Recent 1000 games win rate :36.286%
#  -- 1000 Games WIN : 340 DRAW : 63 LOSS : 597
# Total win rate : 35.580%
#  -- TOTAL Games WIN : 64547 DRAW : 11584 LOSS : 116869
# ========== Training : Episode  194000  ===========
# Recent 1000 games win rate :35.187%
#  -- 1000 Games WIN : 329 DRAW : 65 LOSS : 606
# Total win rate : 35.578%
#  -- TOTAL Games WIN : 64876 DRAW : 11649 LOSS : 117475
# ========== Training : Episode  195000  ===========
# Recent 1000 games win rate :33.191%
#  -- 1000 Games WIN : 311 DRAW : 63 LOSS : 626
# Total win rate : 35.565%
#  -- TOTAL Games WIN : 65187 DRAW : 11712 LOSS : 118101
# ========== Training : Episode  196000  ===========
# Recent 1000 games win rate :36.238%
#  -- 1000 Games WIN : 341 DRAW : 59 LOSS : 600
# Total win rate : 35.569%
#  -- TOTAL Games WIN : 65528 DRAW : 11771 LOSS : 118701
# ========== Training : Episode  197000  ===========
# Recent 1000 games win rate :32.452%
#  -- 1000 Games WIN : 307 DRAW : 54 LOSS : 639
# Total win rate : 35.553%
#  -- TOTAL Games WIN : 65835 DRAW : 11825 LOSS : 119340
# ========== Training : Episode  198000  ===========
# Recent 1000 games win rate :35.175%
#  -- 1000 Games WIN : 331 DRAW : 59 LOSS : 610
# Total win rate : 35.551%
#  -- TOTAL Games WIN : 66166 DRAW : 11884 LOSS : 119950
# ========== Training : Episode  199000  ===========
# Recent 1000 games win rate :34.454%
#  -- 1000 Games WIN : 328 DRAW : 48 LOSS : 624
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 66494 DRAW : 11932 LOSS : 120574
# ========== Training : Episode  200000  ===========
# Recent 1000 games win rate :34.424%
#  -- 1000 Games WIN : 326 DRAW : 53 LOSS : 621
# Total win rate : 35.540%
#  -- TOTAL Games WIN : 66820 DRAW : 11985 LOSS : 121195
# ========== Training : Episode  201000  ===========
# Recent 1000 games win rate :36.052%
#  -- 1000 Games WIN : 336 DRAW : 68 LOSS : 596
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 67156 DRAW : 12053 LOSS : 121791
# ========== Training : Episode  202000  ===========
# Recent 1000 games win rate :37.037%
#  -- 1000 Games WIN : 350 DRAW : 55 LOSS : 595
# Total win rate : 35.550%
#  -- TOTAL Games WIN : 67506 DRAW : 12108 LOSS : 122386
# ========== Training : Episode  203000  ===========
# Recent 1000 games win rate :35.101%
#  -- 1000 Games WIN : 331 DRAW : 57 LOSS : 612
# Total win rate : 35.547%
#  -- TOTAL Games WIN : 67837 DRAW : 12165 LOSS : 122998
# ========== Training : Episode  204000  ===========
# Recent 1000 games win rate :35.138%
#  -- 1000 Games WIN : 331 DRAW : 58 LOSS : 611
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 68168 DRAW : 12223 LOSS : 123609
# ========== Training : Episode  205000  ===========
# Recent 1000 games win rate :34.718%
#  -- 1000 Games WIN : 326 DRAW : 61 LOSS : 613
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 68494 DRAW : 12284 LOSS : 124222
# ========== Training : Episode  206000  ===========
# Recent 1000 games win rate :36.432%
#  -- 1000 Games WIN : 341 DRAW : 64 LOSS : 595
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 68835 DRAW : 12348 LOSS : 124817
# ========== Training : Episode  207000  ===========
# Recent 1000 games win rate :36.190%
#  -- 1000 Games WIN : 342 DRAW : 55 LOSS : 603
# Total win rate : 35.549%
#  -- TOTAL Games WIN : 69177 DRAW : 12403 LOSS : 125420
# ========== Training : Episode  208000  ===========
# Recent 1000 games win rate :35.851%
#  -- 1000 Games WIN : 337 DRAW : 60 LOSS : 603
# Total win rate : 35.550%
#  -- TOTAL Games WIN : 69514 DRAW : 12463 LOSS : 126023
# ========== Training : Episode  209000  ===========
# Recent 1000 games win rate :36.335%
#  -- 1000 Games WIN : 343 DRAW : 56 LOSS : 601
# Total win rate : 35.554%
#  -- TOTAL Games WIN : 69857 DRAW : 12519 LOSS : 126624
# ========== Training : Episode  210000  ===========
# Recent 1000 games win rate :35.456%
#  -- 1000 Games WIN : 334 DRAW : 58 LOSS : 608
# Total win rate : 35.554%
#  -- TOTAL Games WIN : 70191 DRAW : 12577 LOSS : 127232
# ========== Training : Episode  211000  ===========
# Recent 1000 games win rate :36.034%
#  -- 1000 Games WIN : 338 DRAW : 62 LOSS : 600
# Total win rate : 35.556%
#  -- TOTAL Games WIN : 70529 DRAW : 12639 LOSS : 127832
# ========== Training : Episode  212000  ===========
# Recent 1000 games win rate :34.652%
#  -- 1000 Games WIN : 324 DRAW : 65 LOSS : 611
# Total win rate : 35.552%
#  -- TOTAL Games WIN : 70853 DRAW : 12704 LOSS : 128443
# ========== Training : Episode  213000  ===========
# Recent 1000 games win rate :34.995%
#  -- 1000 Games WIN : 330 DRAW : 57 LOSS : 613
# Total win rate : 35.549%
#  -- TOTAL Games WIN : 71183 DRAW : 12761 LOSS : 129056
# ========== Training : Episode  214000  ===========
# Recent 1000 games win rate :37.209%
#  -- 1000 Games WIN : 352 DRAW : 54 LOSS : 594
# Total win rate : 35.557%
#  -- TOTAL Games WIN : 71535 DRAW : 12815 LOSS : 129650
# ========== Training : Episode  215000  ===========
# Recent 1000 games win rate :34.921%
#  -- 1000 Games WIN : 330 DRAW : 55 LOSS : 615
# Total win rate : 35.554%
#  -- TOTAL Games WIN : 71865 DRAW : 12870 LOSS : 130265
# ========== Training : Episode  216000  ===========
# Recent 1000 games win rate :33.794%
#  -- 1000 Games WIN : 318 DRAW : 59 LOSS : 623
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 72183 DRAW : 12929 LOSS : 130888
# ========== Training : Episode  217000  ===========
# Recent 1000 games win rate :36.168%
#  -- 1000 Games WIN : 336 DRAW : 71 LOSS : 593
# Total win rate : 35.549%
#  -- TOTAL Games WIN : 72519 DRAW : 13000 LOSS : 131481
# ========== Training : Episode  218000  ===========
# Recent 1000 games win rate :32.234%
#  -- 1000 Games WIN : 303 DRAW : 60 LOSS : 637
# Total win rate : 35.533%
#  -- TOTAL Games WIN : 72822 DRAW : 13060 LOSS : 132118
# ========== Training : Episode  219000  ===========
# Recent 1000 games win rate :35.474%
#  -- 1000 Games WIN : 337 DRAW : 50 LOSS : 613
# Total win rate : 35.533%
#  -- TOTAL Games WIN : 73159 DRAW : 13110 LOSS : 132731
# ========== Training : Episode  220000  ===========
# Recent 1000 games win rate :35.132%
#  -- 1000 Games WIN : 332 DRAW : 55 LOSS : 613
# Total win rate : 35.531%
#  -- TOTAL Games WIN : 73491 DRAW : 13165 LOSS : 133344
# ========== Training : Episode  221000  ===========
# Recent 1000 games win rate :36.578%
#  -- 1000 Games WIN : 342 DRAW : 65 LOSS : 593
# Total win rate : 35.536%
#  -- TOTAL Games WIN : 73833 DRAW : 13230 LOSS : 133937
# ========== Training : Episode  222000  ===========
# Recent 1000 games win rate :35.332%
#  -- 1000 Games WIN : 330 DRAW : 66 LOSS : 604
# Total win rate : 35.535%
#  -- TOTAL Games WIN : 74163 DRAW : 13296 LOSS : 134541
# ========== Training : Episode  223000  ===========
# Recent 1000 games win rate :34.995%
#  -- 1000 Games WIN : 330 DRAW : 57 LOSS : 613
# Total win rate : 35.533%
#  -- TOTAL Games WIN : 74493 DRAW : 13353 LOSS : 135154
# ========== Training : Episode  224000  ===========
# Recent 1000 games win rate :34.120%
#  -- 1000 Games WIN : 318 DRAW : 68 LOSS : 614
# Total win rate : 35.526%
#  -- TOTAL Games WIN : 74811 DRAW : 13421 LOSS : 135768
# ========== Training : Episode  225000  ===========
# Recent 1000 games win rate :37.315%
#  -- 1000 Games WIN : 353 DRAW : 54 LOSS : 593
# Total win rate : 35.534%
#  -- TOTAL Games WIN : 75164 DRAW : 13475 LOSS : 136361
# ========== Training : Episode  226000  ===========
# Recent 1000 games win rate :35.525%
#  -- 1000 Games WIN : 335 DRAW : 57 LOSS : 608
# Total win rate : 35.534%
#  -- TOTAL Games WIN : 75499 DRAW : 13532 LOSS : 136969
# ========== Training : Episode  227000  ===========
# Recent 1000 games win rate :33.828%
#  -- 1000 Games WIN : 319 DRAW : 57 LOSS : 624
# Total win rate : 35.527%
#  -- TOTAL Games WIN : 75818 DRAW : 13589 LOSS : 137593
# ========== Training : Episode  228000  ===========
# Recent 1000 games win rate :36.735%
#  -- 1000 Games WIN : 342 DRAW : 69 LOSS : 589
# ...
# Recent 1000 games win rate :36.660%
#  -- 1000 Games WIN : 349 DRAW : 48 LOSS : 603
# Total win rate : 35.536%
#  -- TOTAL Games WIN : 309363 DRAW : 55429 LOSS : 561208
# ========== Training : Episode  927000  ===========
# Recent 1000 games win rate :35.393%
#  -- 1000 Games WIN : 338 DRAW : 45 LOSS : 617
# Total win rate : 35.535%
#  -- TOTAL Games WIN : 309701 DRAW : 55474 LOSS : 561825
# ========== Training : Episode  928000  ===========
# Recent 1000 games win rate :35.600%
#  -- 1000 Games WIN : 335 DRAW : 59 LOSS : 606
# Total win rate : 35.536%
#  -- TOTAL Games WIN : 310036 DRAW : 55533 LOSS : 562431
# ========== Training : Episode  929000  ===========
# Recent 1000 games win rate :35.069%
#  -- 1000 Games WIN : 330 DRAW : 59 LOSS : 611
# Total win rate : 35.535%
#  -- TOTAL Games WIN : 310366 DRAW : 55592 LOSS : 563042
# ========== Training : Episode  930000  ===========
# Recent 1000 games win rate :37.553%
#  -- 1000 Games WIN : 353 DRAW : 60 LOSS : 587
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 310719 DRAW : 55652 LOSS : 563629
# ========== Training : Episode  931000  ===========
# Recent 1000 games win rate :35.662%
#  -- 1000 Games WIN : 342 DRAW : 41 LOSS : 617
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 311061 DRAW : 55693 LOSS : 564246
# ========== Training : Episode  932000  ===========
# Recent 1000 games win rate :35.487%
#  -- 1000 Games WIN : 335 DRAW : 56 LOSS : 609
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 311396 DRAW : 55749 LOSS : 564855
# ========== Training : Episode  933000  ===========
# Recent 1000 games win rate :36.508%
#  -- 1000 Games WIN : 345 DRAW : 55 LOSS : 600
# Total win rate : 35.538%
#  -- TOTAL Games WIN : 311741 DRAW : 55804 LOSS : 565455
# ========== Training : Episode  934000  ===========
# Recent 1000 games win rate :35.501%
#  -- 1000 Games WIN : 333 DRAW : 62 LOSS : 605
# Total win rate : 35.538%
#  -- TOTAL Games WIN : 312074 DRAW : 55866 LOSS : 566060
# ========== Training : Episode  935000  ===========
# Recent 1000 games win rate :37.994%
#  -- 1000 Games WIN : 356 DRAW : 63 LOSS : 581
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 312430 DRAW : 55929 LOSS : 566641
# ========== Training : Episode  936000  ===========
# Recent 1000 games win rate :35.829%
#  -- 1000 Games WIN : 335 DRAW : 65 LOSS : 600
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 312765 DRAW : 55994 LOSS : 567241
# ========== Training : Episode  937000  ===========
# Recent 1000 games win rate :36.277%
#  -- 1000 Games WIN : 341 DRAW : 60 LOSS : 599
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 313106 DRAW : 56054 LOSS : 567840
# ========== Training : Episode  938000  ===========
# Recent 1000 games win rate :34.120%
#  -- 1000 Games WIN : 318 DRAW : 68 LOSS : 614
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 313424 DRAW : 56122 LOSS : 568454
# ========== Training : Episode  939000  ===========
# Recent 1000 games win rate :37.085%
#  -- 1000 Games WIN : 346 DRAW : 67 LOSS : 587
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 313770 DRAW : 56189 LOSS : 569041
# ========== Training : Episode  940000  ===========
# Recent 1000 games win rate :37.766%
#  -- 1000 Games WIN : 355 DRAW : 60 LOSS : 585
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 314125 DRAW : 56249 LOSS : 569626
# ========== Training : Episode  941000  ===========
# Recent 1000 games win rate :36.008%
#  -- 1000 Games WIN : 341 DRAW : 53 LOSS : 606
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 314466 DRAW : 56302 LOSS : 570232
# ========== Training : Episode  942000  ===========
# Recent 1000 games win rate :36.238%
#  -- 1000 Games WIN : 341 DRAW : 59 LOSS : 600
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 314807 DRAW : 56361 LOSS : 570832
# ========== Training : Episode  943000  ===========
# Recent 1000 games win rate :34.289%
#  -- 1000 Games WIN : 323 DRAW : 58 LOSS : 619
# Total win rate : 35.544%
#  -- TOTAL Games WIN : 315130 DRAW : 56419 LOSS : 571451
# ========== Training : Episode  944000  ===========
# Recent 1000 games win rate :35.487%
#  -- 1000 Games WIN : 335 DRAW : 56 LOSS : 609
# Total win rate : 35.544%
#  -- TOTAL Games WIN : 315465 DRAW : 56475 LOSS : 572060
# ========== Training : Episode  945000  ===========
# Recent 1000 games win rate :36.218%
#  -- 1000 Games WIN : 339 DRAW : 64 LOSS : 597
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 315804 DRAW : 56539 LOSS : 572657
# ========== Training : Episode  946000  ===========
# Recent 1000 games win rate :34.043%
#  -- 1000 Games WIN : 320 DRAW : 60 LOSS : 620
# Total win rate : 35.543%
#  -- TOTAL Games WIN : 316124 DRAW : 56599 LOSS : 573277
# ========== Training : Episode  947000  ===========
# Recent 1000 games win rate :37.780%
#  -- 1000 Games WIN : 354 DRAW : 63 LOSS : 583
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 316478 DRAW : 56662 LOSS : 573860
# ========== Training : Episode  948000  ===========
# Recent 1000 games win rate :35.599%
#  -- 1000 Games WIN : 330 DRAW : 73 LOSS : 597
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 316808 DRAW : 56735 LOSS : 574457
# ========== Training : Episode  949000  ===========
# Recent 1000 games win rate :36.848%
#  -- 1000 Games WIN : 346 DRAW : 61 LOSS : 593
# Total win rate : 35.547%
#  -- TOTAL Games WIN : 317154 DRAW : 56796 LOSS : 575050
# ========== Training : Episode  950000  ===========
# Recent 1000 games win rate :36.451%
#  -- 1000 Games WIN : 343 DRAW : 59 LOSS : 598
# Total win rate : 35.548%
#  -- TOTAL Games WIN : 317497 DRAW : 56855 LOSS : 575648
# ========== Training : Episode  951000  ===========
# Recent 1000 games win rate :32.489%
#  -- 1000 Games WIN : 308 DRAW : 52 LOSS : 640
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 317805 DRAW : 56907 LOSS : 576288
# ========== Training : Episode  952000  ===========
# Recent 1000 games win rate :36.402%
#  -- 1000 Games WIN : 348 DRAW : 44 LOSS : 608
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 318153 DRAW : 56951 LOSS : 576896
# ========== Training : Episode  953000  ===========
# Recent 1000 games win rate :34.557%
#  -- 1000 Games WIN : 320 DRAW : 74 LOSS : 606
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 318473 DRAW : 57025 LOSS : 577502
# ========== Training : Episode  954000  ===========
# Recent 1000 games win rate :35.722%
#  -- 1000 Games WIN : 339 DRAW : 51 LOSS : 610
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 318812 DRAW : 57076 LOSS : 578112
# ========== Training : Episode  955000  ===========
# Recent 1000 games win rate :31.842%
#  -- 1000 Games WIN : 299 DRAW : 61 LOSS : 640
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 319111 DRAW : 57137 LOSS : 578752
# ========== Training : Episode  956000  ===========
# Recent 1000 games win rate :31.652%
#  -- 1000 Games WIN : 295 DRAW : 68 LOSS : 637
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 319406 DRAW : 57205 LOSS : 579389
# ========== Training : Episode  957000  ===========
# Recent 1000 games win rate :35.714%
#  -- 1000 Games WIN : 335 DRAW : 62 LOSS : 603
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 319741 DRAW : 57267 LOSS : 579992
# ========== Training : Episode  958000  ===========
# Recent 1000 games win rate :34.919%
#  -- 1000 Games WIN : 323 DRAW : 75 LOSS : 602
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 320064 DRAW : 57342 LOSS : 580594
# ========== Training : Episode  959000  ===========
# Recent 1000 games win rate :35.432%
#  -- 1000 Games WIN : 332 DRAW : 63 LOSS : 605
# Total win rate : 35.537%
#  -- TOTAL Games WIN : 320396 DRAW : 57405 LOSS : 581199
# ========== Training : Episode  960000  ===========
# Recent 1000 games win rate :37.276%
#  -- 1000 Games WIN : 353 DRAW : 53 LOSS : 594
# Total win rate : 35.538%
#  -- TOTAL Games WIN : 320749 DRAW : 57458 LOSS : 581793
# ========== Training : Episode  961000  ===========
# Recent 1000 games win rate :34.681%
#  -- 1000 Games WIN : 326 DRAW : 60 LOSS : 614
# Total win rate : 35.538%
#  -- TOTAL Games WIN : 321075 DRAW : 57518 LOSS : 582407
# ========== Training : Episode  962000  ===========
# Recent 1000 games win rate :37.158%
#  -- 1000 Games WIN : 353 DRAW : 50 LOSS : 597
# Total win rate : 35.539%
#  -- TOTAL Games WIN : 321428 DRAW : 57568 LOSS : 583004
# ========== Training : Episode  963000  ===========
# Recent 1000 games win rate :35.813%
#  -- 1000 Games WIN : 337 DRAW : 59 LOSS : 604
# Total win rate : 35.539%
#  -- TOTAL Games WIN : 321765 DRAW : 57627 LOSS : 583608
# ========== Training : Episode  964000  ===========
# Recent 1000 games win rate :35.269%
#  -- 1000 Games WIN : 334 DRAW : 53 LOSS : 613
# Total win rate : 35.539%
#  -- TOTAL Games WIN : 322099 DRAW : 57680 LOSS : 584221
# ========== Training : Episode  965000  ===========
# Recent 1000 games win rate :34.362%
#  -- 1000 Games WIN : 323 DRAW : 60 LOSS : 617
# Total win rate : 35.538%
#  -- TOTAL Games WIN : 322422 DRAW : 57740 LOSS : 584838
# ========== Training : Episode  966000  ===========
# Recent 1000 games win rate :38.983%
#  -- 1000 Games WIN : 368 DRAW : 56 LOSS : 576
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 322790 DRAW : 57796 LOSS : 585414
# ========== Training : Episode  967000  ===========
# Recent 1000 games win rate :35.837%
#  -- 1000 Games WIN : 334 DRAW : 68 LOSS : 598
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 323124 DRAW : 57864 LOSS : 586012
# ========== Training : Episode  968000  ===========
# Recent 1000 games win rate :35.669%
#  -- 1000 Games WIN : 336 DRAW : 58 LOSS : 606
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 323460 DRAW : 57922 LOSS : 586618
# ========== Training : Episode  969000  ===========
# Recent 1000 games win rate :35.827%
#  -- 1000 Games WIN : 340 DRAW : 51 LOSS : 609
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 323800 DRAW : 57973 LOSS : 587227
# ========== Training : Episode  970000  ===========
# Recent 1000 games win rate :35.474%
#  -- 1000 Games WIN : 337 DRAW : 50 LOSS : 613
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 324137 DRAW : 58023 LOSS : 587840
# ========== Training : Episode  971000  ===========
# Recent 1000 games win rate :36.797%
#  -- 1000 Games WIN : 347 DRAW : 57 LOSS : 596
# Total win rate : 35.544%
#  -- TOTAL Games WIN : 324484 DRAW : 58080 LOSS : 588436
# ========== Training : Episode  972000  ===========
# Recent 1000 games win rate :33.904%
#  -- 1000 Games WIN : 317 DRAW : 65 LOSS : 618
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 324801 DRAW : 58145 LOSS : 589054
# ========== Training : Episode  973000  ===========
# Recent 1000 games win rate :37.726%
#  -- 1000 Games WIN : 355 DRAW : 59 LOSS : 586
# Total win rate : 35.544%
#  -- TOTAL Games WIN : 325156 DRAW : 58204 LOSS : 589640
# ========== Training : Episode  974000  ===========
# Recent 1000 games win rate :35.484%
#  -- 1000 Games WIN : 330 DRAW : 70 LOSS : 600
# Total win rate : 35.544%
#  -- TOTAL Games WIN : 325486 DRAW : 58274 LOSS : 590240
# ========== Training : Episode  975000  ===========
# Recent 1000 games win rate :36.614%
#  -- 1000 Games WIN : 346 DRAW : 55 LOSS : 599
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 325832 DRAW : 58329 LOSS : 590839
# ========== Training : Episode  976000  ===========
# Recent 1000 games win rate :36.017%
#  -- 1000 Games WIN : 340 DRAW : 56 LOSS : 604
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 326172 DRAW : 58385 LOSS : 591443
# ========== Training : Episode  977000  ===========
# Recent 1000 games win rate :36.026%
#  -- 1000 Games WIN : 339 DRAW : 59 LOSS : 602
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 326511 DRAW : 58444 LOSS : 592045
# ========== Training : Episode  978000  ===========
# Recent 1000 games win rate :39.979%
#  -- 1000 Games WIN : 381 DRAW : 47 LOSS : 572
# Total win rate : 35.551%
#  -- TOTAL Games WIN : 326892 DRAW : 58491 LOSS : 592617
# ========== Training : Episode  979000  ===========
# Recent 1000 games win rate :34.545%
#  -- 1000 Games WIN : 323 DRAW : 65 LOSS : 612
# Total win rate : 35.550%
#  -- TOTAL Games WIN : 327215 DRAW : 58556 LOSS : 593229
# ========== Training : Episode  980000  ===========
# Recent 1000 games win rate :33.546%
#  -- 1000 Games WIN : 315 DRAW : 61 LOSS : 624
# Total win rate : 35.548%
#  -- TOTAL Games WIN : 327530 DRAW : 58617 LOSS : 593853
# ========== Training : Episode  981000  ===========
# Recent 1000 games win rate :35.075%
#  -- 1000 Games WIN : 329 DRAW : 62 LOSS : 609
# Total win rate : 35.547%
#  -- TOTAL Games WIN : 327859 DRAW : 58679 LOSS : 594462
# ========== Training : Episode  982000  ===========
# Recent 1000 games win rate :35.933%
#  -- 1000 Games WIN : 341 DRAW : 51 LOSS : 608
# Total win rate : 35.548%
#  -- TOTAL Games WIN : 328200 DRAW : 58730 LOSS : 595070
# ========== Training : Episode  983000  ===========
# Recent 1000 games win rate :32.725%
#  -- 1000 Games WIN : 305 DRAW : 68 LOSS : 627
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 328505 DRAW : 58798 LOSS : 595697
# ========== Training : Episode  984000  ===========
# Recent 1000 games win rate :36.809%
#  -- 1000 Games WIN : 346 DRAW : 60 LOSS : 594
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 328851 DRAW : 58858 LOSS : 596291
# ========== Training : Episode  985000  ===========
# Recent 1000 games win rate :34.916%
#  -- 1000 Games WIN : 331 DRAW : 52 LOSS : 617
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 329182 DRAW : 58910 LOSS : 596908
# ========== Training : Episode  986000  ===========
# Recent 1000 games win rate :34.494%
#  -- 1000 Games WIN : 327 DRAW : 52 LOSS : 621
# Total win rate : 35.544%
#  -- TOTAL Games WIN : 329509 DRAW : 58962 LOSS : 597529
# ========== Training : Episode  987000  ===========
# Recent 1000 games win rate :31.090%
#  -- 1000 Games WIN : 291 DRAW : 64 LOSS : 645
# Total win rate : 35.540%
#  -- TOTAL Games WIN : 329800 DRAW : 59026 LOSS : 598174
# ========== Training : Episode  988000  ===========
# Recent 1000 games win rate :35.528%
#  -- 1000 Games WIN : 340 DRAW : 43 LOSS : 617
# Total win rate : 35.540%
#  -- TOTAL Games WIN : 330140 DRAW : 59069 LOSS : 598791
# ========== Training : Episode  989000  ===========
# Recent 1000 games win rate :37.131%
#  -- 1000 Games WIN : 352 DRAW : 52 LOSS : 596
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 330492 DRAW : 59121 LOSS : 599387
# ========== Training : Episode  990000  ===========
# Recent 1000 games win rate :35.684%
#  -- 1000 Games WIN : 339 DRAW : 50 LOSS : 611
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 330831 DRAW : 59171 LOSS : 599998
# ========== Training : Episode  991000  ===========
# Recent 1000 games win rate :37.407%
#  -- 1000 Games WIN : 352 DRAW : 59 LOSS : 589
# Total win rate : 35.543%
#  -- TOTAL Games WIN : 331183 DRAW : 59230 LOSS : 600587
# ========== Training : Episode  992000  ===========
# Recent 1000 games win rate :37.700%
#  -- 1000 Games WIN : 354 DRAW : 61 LOSS : 585
# Total win rate : 35.546%
#  -- TOTAL Games WIN : 331537 DRAW : 59291 LOSS : 601172
# ========== Training : Episode  993000  ===========
# Recent 1000 games win rate :34.811%
#  -- 1000 Games WIN : 322 DRAW : 75 LOSS : 603
# Total win rate : 35.545%
#  -- TOTAL Games WIN : 331859 DRAW : 59366 LOSS : 601775
# ========== Training : Episode  994000  ===========
# Recent 1000 games win rate :33.157%
#  -- 1000 Games WIN : 313 DRAW : 56 LOSS : 631
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 332172 DRAW : 59422 LOSS : 602406
# ========== Training : Episode  995000  ===========
# Recent 1000 games win rate :35.745%
#  -- 1000 Games WIN : 336 DRAW : 60 LOSS : 604
# Total win rate : 35.543%
#  -- TOTAL Games WIN : 332508 DRAW : 59482 LOSS : 603010
# ========== Training : Episode  996000  ===========
# Recent 1000 games win rate :34.615%
#  -- 1000 Games WIN : 324 DRAW : 64 LOSS : 612
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 332832 DRAW : 59546 LOSS : 603622
# ========== Training : Episode  997000  ===========
# Recent 1000 games win rate :36.681%
#  -- 1000 Games WIN : 347 DRAW : 54 LOSS : 599
# Total win rate : 35.543%
#  -- TOTAL Games WIN : 333179 DRAW : 59600 LOSS : 604221
# ========== Training : Episode  998000  ===========
# Recent 1000 games win rate :34.123%
#  -- 1000 Games WIN : 317 DRAW : 71 LOSS : 612
# Total win rate : 35.541%
#  -- TOTAL Games WIN : 333496 DRAW : 59671 LOSS : 604833
# ========== Training : Episode  999000  ===========
# Recent 1000 games win rate :35.646%
#  -- 1000 Games WIN : 334 DRAW : 63 LOSS : 603
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 333830 DRAW : 59734 LOSS : 605436
# ========== Training : Episode  1000000  ===========
# Recent 1000 games win rate :36.296%
#  -- 1000 Games WIN : 343 DRAW : 55 LOSS : 602
# Total win rate : 35.542%
#  -- TOTAL Games WIN : 334173 DRAW : 59789 LOSS : 606038

# %% [markdown]
# ## 8. 학습 결과 시각화

# %%
print("Q-value with Usable Ace")
plot_q_val(agent, usable_ace=True)
print("Q-value without Usable Ace")
plot_q_val(agent, usable_ace=False)
print("Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)")
usable_result = plot_action(agent, usable_ace=True)
print("Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)")
no_usable_result = plot_action(agent, usable_ace=False)
# Out:
# Q-value with Usable Ace
# Q-value without Usable Ace
# Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)
# Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)

# %% [markdown]
# ----
# ## 9. 과제
#
# ### 목표
# 위 코드로부터 최적 Policy를 학습시킨 Agent를 사용하여, 블랙잭 게임을 시뮬레이션한 뒤 승률을 계산.
#
# ### 초기 설정
#  - 플레이어는 1,000,000번의 에피소드로부터 최적 Policy를 학습
#  - 플레이어의 초기 자금 : 10,000 달러
#  - 플레이어는 게임 참가 시 10 달러를 지불, 결과에 따라 금액을 획득
#      - 승리 시 : 20 달러 획득
#      - 무승부 시 : 10 달러 획득
#      - 패배 시 : 0 달러 획득
#
# ### 요구사항
#  - 플레이어와 딜러가 1,000번의 게임을 진행
#  - 1,000번의 게임 후 플레이어의 승률을 계산
#  - 매 게임 별 플레이어의 소지금 변화를 그래프로 시각화
#
# #### * HINT : MonteCarlo 클래스의 generate_episode(), train() 메소드를 참고할 것
# ----
# ### (과제 1) 1,000번의 게임 진행

# %%
############### 코드 작성 ##############################
from pprint import pprint

resepisode = list()
moneyList = list()
# moneyList = []
cnt = 0
playerWincnt = 0
money = 10000  #플레이어 초기 자본은 10,000달러


for i in range(1000):
#     money -= 10    #게임 참가 시 10달러 내야함
    resepisode = mc_es.generate_episode(dealer, agent, deck)      
    
    length = len(resepisode)
    if resepisode[length-1][2] == 0:  #무승부로 끝남
        moneyList.append(money)
    
  
    else :
        for j in range(length):
            if resepisode[j][2] == 1 :      #플레이어 승
                cnt += 1
                playerWincnt += 1
                money += 10
                moneyList.append(money)
            elif resepisode[j][2] == -1 :    #플레이어 패
                cnt += 1
                money -= 10
                moneyList.append(money)
            else :
                continue


len(moneyList)


########################################################
# Out:
# 1000

# %% [markdown]
# ### (과제 2) 플레이어의 승률을 계산

# %%
############### 코드 작성 ##############################


#플레이어 승률 : (승리수)/(승리수 + 패배수)

win = (playerWincnt / cnt) * 100

print('Win Rate of Player is %f'%win)



########################################################
# Out:
# Win Rate of Player is 39.079229

# %% [markdown]
# ### (과제 3) 플레이어의 소지금 변화를 그래프로 시각화

# %%
############### 코드 작성 ##############################


import matplotlib.pyplot as plt

plt.plot(range(len(moneyList)), moneyList)
plt.ylabel('money of player')
plt.show()


########################################################

# %%
plt.plot(range(len(moneyList)), moneyList, 'ro')
plt.ylabel('money of player')
plt.show()

# %%
plt.plot(range(len(moneyList)), moneyList, 'r--')
plt.ylabel('money of player')
plt.show()

# %%
plt.plot(range(len(moneyList)), moneyList, 'g^')
plt.ylabel('money of player')
plt.show()

# %%
plt.plot(range(len(moneyList)), moneyList, 'bs')
plt.ylabel('money of player')
plt.show()

# %% [markdown]
# ## 추가 과제 : 플레이어의 승률 높이기
# State를 수정하여 승률이 더 높은 policy를 찾기
#
# 기존 코드의 수정 필요
#  - 딜러는 게임이 끝났을 때, 남은 카드의 수를 확인
#  - 15장 이상이라면 해당 덱을 다음 게임에서 그대로 사용
#  - 15장 미만이라면 52장의 셔플된 새로운 카드를 기존 덱에 추가

# %%
############### 코드 작성 ##############################



#Deck 클래스에 작성 


########################################################

# %% [markdown]
# ---
# ### 참고자료
# [1] Reinforcement Learning - An Introduction (Richard S. Sutton, Andreow G. Barto), 2nd edition, p.120-124 https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf <br>
# [2] matplotlib.pyplot.plot Documentation, https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html <br>
# [3] matplotlib.pyplot.plot Examples https://matplotlib.org/tutorials/introductory/pyplot.html
